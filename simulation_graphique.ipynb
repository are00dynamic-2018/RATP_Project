# %%
# %matplotlib inline

from pylab import *

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
from tkinter import * 


'''fenetre = Tk()

photo = PhotoImage(master=fenetre, file="cerclemetro.pgm")

canvas = Canvas(fenetre,width=869, height=720)
canvas.create_image(0, 0, anchor=NW, image=photo)

"""ligne 1 la defense -> chateau de vincenne"""

canvas.create_oval(37,208,44,215,fill='red')
canvas.create_oval(67,221,74,228,fill='red')
canvas.create_oval(99,234,106,241,fill='red')
canvas.create_oval(130,247,137,254,fill='red')
canvas.create_oval(171,265,178,272,fill='red')
canvas.create_oval(195,276,202,283,fill='red')
canvas.create_oval(221,295,229,281,fill='red') # charles de gaule etoile
canvas.create_oval(268,316,275,323,fill='red')
canvas.create_oval(260,342,271,349,fill='red') # Franklin D Roosevelt
canvas.create_oval(296,364,303,371,fill='red') # champ elysee
canvas.create_oval(331,368,341,375,fill='red') # concorde
canvas.create_oval(359,373,366,380,fill='red')
canvas.create_oval(381,387,388,377,fill='red') # Palais royal
canvas.create_oval(405,379,412,386,fill='red')
canvas.create_oval(460,390,467,397,fill='red') # Chatelet
canvas.create_oval(522,397,529,404,fill='red') # Hotel de ville
canvas.create_oval(545,400,552,407,fill='red')
canvas.create_oval(590,404,597,413,fill='red') # Bastille
canvas.create_oval(598,440,604,455,fill='red') # Gare de lyon
canvas.create_oval(627,462,634,469,fill='red') # Reuilly diderot
canvas.create_oval(701,484,708,502,fill='red') # Nation
canvas.create_oval(725,505,732,512,fill='red')
canvas.create_oval(756,518,763,525,fill='red')
canvas.create_oval(787,531,794,538,fill='red')
canvas.create_oval(818,544,825,551,fill='red')

"""ligne 2 Nation -> Porte dauphine"""

canvas.create_oval(701,484,708,502,fill='red') # Nation
canvas.create_oval(687,450,694,457,fill='red')
canvas.create_oval(695,408,702,415,fill='red')
canvas.create_oval(695,364,702,371,fill='red')
canvas.create_oval(685,321,692,328,fill='red') # Pere Lachaise
canvas.create_oval(680,303,687,310,fill='red')
canvas.create_oval(673,286,680,293,fill='red')
canvas.create_oval(664,269,671,276,fill='red') # Beleville
canvas.create_oval(650,250,657,257,fill='red')
canvas.create_oval(622,217,629,224,fill='red') # Jaures
canvas.create_oval(610,200,617,207,fill='pink') # Stalingrad
canvas.create_oval(569,179,576,186,fill='red')
canvas.create_oval(536,161,543,168,fill='blue') # Barbes
canvas.create_oval(476,154,483,161,fill='red')
canvas.create_oval(416,156,423,163,fill='red') # pigale
canvas.create_oval(382,167,389,174,fill='red')
canvas.create_oval(347,181,354,188,fill='red') # Porte de clichy
canvas.create_oval(315,201,322,208,fill='red')
canvas.create_oval(288,228,295,235,fill='red') # Villiers
canvas.create_oval(273,244,280,251,fill='red') 
canvas.create_oval(260,261,267,268,fill='red')
canvas.create_oval(251,278,258,285,fill='red')
canvas.create_oval(221,295,229,281,fill='red') # Charles de gaulle etoile
canvas.create_oval(189,327,196,334,fill='red')
canvas.create_oval(184,348,191,355,fill='red')

"""ligne 3 Galieni -> Levalois"""

canvas.create_oval(837,277,844,284,fill='#cdcd0d')
canvas.create_oval(811,284,818,291,fill='#cdcd0d')
canvas.create_oval(770,293,777,304,fill='#cdcd0d') # Gambetta
canvas.create_oval(685,321,692,328,fill='#cdcd0d') # Pere Lachaise
canvas.create_oval(647,316,654,323,fill='#cdcd0d')
canvas.create_oval(637,294,644,301,fill='#cdcd0d')
canvas.create_oval(571,318,582,328,fill='green') # Republique
canvas.create_oval(545,333,552,340,fill='brown') # Temple
canvas.create_oval(525,347,532,357,fill='brown') # art et metier
canvas.create_oval(485,330,492,337,fill='magenta') # reaumur sebastopol
canvas.create_oval(461,325,468,332,fill='#cdcd0d')
canvas.create_oval(440,332,447,339,fill='#cdcd0d')
canvas.create_oval(423,342,430,349,fill='#cdcd0d')
canvas.create_oval(389,321,396,328,fill='pink') # opera
canvas.create_oval(365,298,372,305,fill='#cdcd0d') # Havre caumartin
canvas.create_oval(337,273,347,281,fill='red') # saint lazare
canvas.create_oval(312,250,319,257,fill='#cdcd0d')
canvas.create_oval(288,228,295,235,fill='#cdcd0d') # villiers
canvas.create_oval(268,209,275,216,fill='#cdcd0d')
canvas.create_oval(251,193,258,200,fill='#cdcd0d')
canvas.create_oval(231,172,238,179,fill='#cdcd0d')
canvas.create_oval(214,158,221,165,fill='#cdcd0d')
canvas.create_oval(201,146,208,153,fill='#cdcd0d')
canvas.create_oval(188,134,195,141,fill='#cdcd0d')
canvas.create_oval(174,120,181,127,fill='#cdcd0d')

"""ligne 3bis Gambetta -> Porte des lilas"""

canvas.create_oval(770,293,777,304,fill='cyan') # Gambetta
canvas.create_oval(804,261,811,268,fill='cyan')
canvas.create_oval(793,232,800,239,fill='red')
canvas.create_oval(776,204,783,211,fill='brown') # porte des lilas

"""ligne 4 Mairie de montrouge -> porte de clignancourt"""

canvas.create_oval(329,699,336,706,fill='magenta')
canvas.create_oval(338,675,345,682,fill='magenta')
canvas.create_oval(348,652,355,659,fill='magenta')
canvas.create_oval(358,629,365,636,fill='magenta')
canvas.create_oval(369,606,379,613,fill='green') # denfert rochereau
canvas.create_oval(350,595,357,602,fill='red') # Ragdal
canvas.create_oval(334,579,341,586,fill='red')
canvas.create_oval(300,555,312,570,fill='green') # Montparnasse Bienvenue
canvas.create_oval(353,510,360,517,fill='magenta')
canvas.create_oval(372,492,379,499,fill='magenta')
canvas.create_oval(392,466,399,473,fill='magenta')
canvas.create_oval(416,457,423,464,fill='magenta') # Odeon
canvas.create_oval(434,451,441,458,fill='magenta')
canvas.create_oval(443,428,450,435,fill='magenta')
canvas.create_oval(460,390,467,397,fill='red') # Chatelet
canvas.create_oval(466,375,473,382,fill='magenta') # Les Halles
canvas.create_oval(475,353,482,360,fill='magenta')
canvas.create_oval(485,330,492,337,fill='magenta') # reaumur sebastopol
canvas.create_oval(499,298,506,305,fill='magenta') # starsbourg saint denis
canvas.create_oval(509,273,516,280,fill='magenta') 
canvas.create_oval(530,215,541,222,fill='pink') # Gare de l'est
canvas.create_oval(545,189,559,198,fill='magenta') # Gare du nord
canvas.create_oval(536,161,543,168,fill='blue') # Barbes
canvas.create_oval(525,137,532,144,fill='magenta')
canvas.create_oval(528,116,535,123,fill='green') # marcadet poissonier
canvas.create_oval(536,92,543,99,fill='magenta')
canvas.create_oval(540,70,547,77,fill='magenta')


"""ligne 5 Bobigny -> Place d'italie"""

canvas.create_oval(750,122,757,129,fill='orange')
canvas.create_oval(735,140,742,147,fill='orange')
canvas.create_oval(718,155,725,162,fill='orange')
canvas.create_oval(700,171,707,178,fill='orange')
canvas.create_oval(683,186,690,193,fill='orange')
canvas.create_oval(667,202,674,209,fill='orange')
canvas.create_oval(650,218,657,225,fill='orange')
canvas.create_oval(622,217,629,224,fill='orange') # Jaures
canvas.create_oval(610,200,617,207,fill='pink') # Stalingrad
canvas.create_oval(545,189,559,198,fill='orange') # Gare du nord
canvas.create_oval(530,215,541,222,fill='pink') # Gare de l'est
canvas.create_oval(542,284,549,291,fill='orange')
canvas.create_oval(571,318,582,328,fill='green') # Republique
canvas.create_oval(585,342,592,349,fill='green') # Oberkampf
canvas.create_oval(589,361,596,368,fill='orange')
canvas.create_oval(591,379,598,386,fill='orange')
canvas.create_oval(590,404,597,413,fill='red') # Bastille
canvas.create_oval(540,581,547,588,fill='orange')
canvas.create_oval(520,532,527,539,fill='orange') # Gare d'austerlitz
canvas.create_oval(542,487,549,494,fill='orange')
canvas.create_oval(574,454,581,461,fill='orange')
canvas.create_oval(523,612,530,622,fill='blue') # Place d'italie

"""ligne 6 Nation -> Charles de Gaulle Etoile"""

canvas.create_oval(701,484,708,502,fill='red') # Nation
canvas.create_oval(672,497,679,505,fill='red')
canvas.create_oval(664,510,671,517,fill='green')
canvas.create_oval(652,523,659,530,fill='violet') # Daumesnil
canvas.create_oval(644,539,651,546,fill='green') 
canvas.create_oval(630,552,637,559,fill='green') # Bercy   
canvas.create_oval(600,581,607,588,fill='green')
canvas.create_oval(579,595,586,602,fill='green')
canvas.create_oval(550,608,557,615,fill='green')
canvas.create_oval(523,612,530,622,fill='blue') # Palace d'italie
canvas.create_oval(487,623,494,630,fill='green')
canvas.create_oval(449,624,456,631,fill='green')
canvas.create_oval(412,619,419,626,fill='red')
canvas.create_oval(369,606,379,613,fill='green') # Denfert rochereau
canvas.create_oval(350,595,357,602,fill='red') # Ragdal
canvas.create_oval(325,583,332,590,fill='red')
canvas.create_oval(300,555,312,570,fill='green') # Montparnasse Bienvenue
canvas.create_oval(279,536,286,543,fill='green') # pasteur
canvas.create_oval(268,526,275,533,fill='red')
canvas.create_oval(260,514,267,521,fill='red')
canvas.create_oval(253,499,260,506,fill='violet') # la motte picquet grenelle
canvas.create_oval(238,462,245,469,fill='red')
canvas.create_oval(230,438,237,445,fill='red')
canvas.create_oval(225,416,232,423,fill='red')
canvas.create_oval(224,389,231,396,fill='green') # Trocadero
canvas.create_oval(226,359,233,366,fill='red')
canvas.create_oval(230,336,237,343,fill='red')
canvas.create_oval(221,295,229,281,fill='red') # Charles de gaulle etoile


"""ligne 7 la courneuve -> maison blanche """

canvas.create_oval(704,80,711,87,fill='pink')
canvas.create_oval(691,97,698,104,fill='pink')
canvas.create_oval(678,114,685,121,fill='pink')
canvas.create_oval(665,130,672,137,fill='pink')
canvas.create_oval(651,146,658,153,fill='pink')
canvas.create_oval(638,163,645,170,fill='pink')
canvas.create_oval(624,184,631,191,fill='pink')
canvas.create_oval(610,200,617,207,fill='pink') # Stalingrad
canvas.create_oval(593,222,600,229,fill='pink') # Louis blanc
canvas.create_oval(576,225,583,232,fill='pink') 
canvas.create_oval(530,215,541,222,fill='pink') # Gare de l'est
canvas.create_oval(493,260,500,267,fill='pink')
canvas.create_oval(454,256,461,263,fill='pink')
canvas.create_oval(415,264,422,271,fill='pink')
canvas.create_oval(397,292,404,299,fill='pink') # Chaussee d'antin Lafayette
canvas.create_oval(389,321,396,328,fill='pink') # opera
canvas.create_oval(370,349,377,356,fill='pink') # pyramide
canvas.create_oval(381,387,388,377,fill='red') # Palais royal
canvas.create_oval(415,386,422,393,fill='pink')
canvas.create_oval(460,390,467,397,fill='red') # Chatelet
canvas.create_oval(470,416,477,423,fill='pink')
canvas.create_oval(477,434,484,441,fill='pink')
canvas.create_oval(494,511,501,518,fill='pink') # jussieu
canvas.create_oval(501,537,508,544,fill='pink')
canvas.create_oval(509,563,516,570,fill='pink')
canvas.create_oval(516,588,523,595,fill='pink')
canvas.create_oval(523,612,530,622,fill='blue') # Place d'italie
canvas.create_oval(528,634,535,641,fill='pink')
canvas.create_oval(534,651,541,658,fill='pink')


"""ligne 7bis Louis Blanc -> Pres saint gervais """

canvas.create_oval(593,222,600,229,fill='pink') # Louis blanc
canvas.create_oval(622,217,629,224,fill='orange') # Jaures
canvas.create_oval(658,240,665,247,fill='green')
canvas.create_oval(676,226,683,233,fill='green')
canvas.create_oval(695,212,702,219,fill='green')
canvas.create_oval(713,198,720,205,fill='green')
canvas.create_oval(742,200,749,207,fill='green')
canvas.create_oval(738,224,745,231,fill='brown') # place des fetes

"""ligne 8 Balard -> Creteil """

canvas.create_oval(137,562,144,569,fill='violet')
canvas.create_oval(159,553,166,560,fill='violet')
canvas.create_oval(180,541,187,548,fill='violet')
canvas.create_oval(200,530,207,537,fill='violet')
canvas.create_oval(224,514,231,521,fill='violet')
canvas.create_oval(253,499,260,506,fill='violet') # la motte picquet grenelle
canvas.create_oval(277,487,284,494,fill='violet')
canvas.create_oval(269,449,276,456,fill='red')
canvas.create_oval(298,424,305,431,fill='red') # invalide
canvas.create_oval(331,368,341,375,fill='red') # concorde
canvas.create_oval(370,349,377,356,fill='pink') # pyramide
canvas.create_oval(389,321,396,328,fill='pink') # opera
canvas.create_oval(418,300,425,307,fill='violet') # richelieu drouot
canvas.create_oval(448,294,455,301,fill='violet') # Grand boulevard
canvas.create_oval(477,291,484,298,fill='red') # Bonne nouvelle
canvas.create_oval(499,298,506,305,fill='magenta') # starsbourg saint denis
canvas.create_oval(571,318,582,328,fill='green') # Republique
canvas.create_oval(548,354,555,361,fill='violet')
canvas.create_oval(555,372,562,379,fill='violet')
canvas.create_oval(555,390,562,397,fill='violet')
canvas.create_oval(590,404,597,413,fill='red') # Bastille
canvas.create_oval(628,407,635,414,fill='red')
canvas.create_oval(635,437,642,444,fill='red')
canvas.create_oval(627,462,634,469,fill='red') # Reuilly diderot
canvas.create_oval(624,502,631,509,fill='violet')
canvas.create_oval(652,523,659,530,fill='violet') # Daumesnil
canvas.create_oval(672,538,679,545,fill='violet')
canvas.create_oval(685,547,692,554,fill='violet')
canvas.create_oval(698,556,705,563,fill='violet')
canvas.create_oval(711,565,718,572,fill='violet')
canvas.create_oval(724,574,731,581,fill='violet')
canvas.create_oval(737,583,744,590,fill='violet')
canvas.create_oval(750,592,757,599,fill='violet')
canvas.create_oval(763,601,770,608,fill='violet')
canvas.create_oval(777,611,784,618,fill='violet')
canvas.create_oval(791,621,798,628,fill='violet')
canvas.create_oval(804,630,811,637,fill='violet')
canvas.create_oval(820,641,827,648,fill='red')
           
"""ligne 9 pont de sevre -> montreuil """

canvas.create_oval(30,571,37,578,fill='green')
canvas.create_oval(50,563,57,570,fill='green')
canvas.create_oval(70,553,77,560,fill='green')
canvas.create_oval(91,544,98,551,fill='green')
canvas.create_oval(112,537,119,544,fill='green')
canvas.create_oval(116,513,123,520,fill='green')
canvas.create_oval(107,484,114,491,fill='green')
canvas.create_oval(98,448,105,455,fill='green')
canvas.create_oval(94,410,101,417,fill='green')
canvas.create_oval(148,388,155,395,fill='green')
canvas.create_oval(184,390,191,397,fill='green')
canvas.create_oval(224,389,231,396,fill='green') # Trocadero
canvas.create_oval(247,390,254,397,fill='green')
canvas.create_oval(261,375,268,382,fill='green')
canvas.create_oval(260,342,271,349,fill='red') # Franklin D Roosevelt
canvas.create_oval(285,338,292,345,fill='green')
canvas.create_oval(306,329,313,336,fill='red') # miromesnil
canvas.create_oval(335,290,342,297,fill='red') # saint augustin
canvas.create_oval(365,298,372,305,fill='green') # Havre caumartin
canvas.create_oval(397,292,404,299,fill='pink') # Chaussee d'antin Lafayette
canvas.create_oval(418,300,425,307,fill='violet') # richelieu drouot
canvas.create_oval(448,294,455,301,fill='violet') # Grand boulevard
canvas.create_oval(477,291,484,298,fill='red') # Bonne nouvelle
canvas.create_oval(499,298,506,305,fill='magenta') # starsbourg saint deni
canvas.create_oval(571,318,582,328,fill='green') # Republique
canvas.create_oval(585,342,592,349,fill='green') # oberkampf
canvas.create_oval(639,342,646,349,fill='green')
canvas.create_oval(660,370,667,377,fill='green')
canvas.create_oval(660,404,667,411,fill='green')
canvas.create_oval(654,444,661,451,fill='green')
canvas.create_oval(701,484,708,502,fill='red') # Nation
canvas.create_oval(728,472,735,479,fill='green')
canvas.create_oval(734,446,741,453,fill='green')
canvas.create_oval(748,426,755,433,fill='green')
canvas.create_oval(780,430,787,437,fill='green')
canvas.create_oval(814,435,821,442,fill='green')
canvas.create_oval(848,440,855,447,fill='green')

"""ligne 10 Javel -> Gare d'austerlitz"""

canvas.create_oval(182,488,189,495,fill='brown')
canvas.create_oval(205,480,212,487,fill='brown')
canvas.create_oval(229,472,236,479,fill='brown')
canvas.create_oval(253,499,260,506,fill='violet') # la motte picquet grenelle
canvas.create_oval(275,508,282,515,fill='red')
canvas.create_oval(320,478,327,485,fill='red') # duroc
canvas.create_oval(337,467,344,474,fill='red')
canvas.create_oval(361,470,368,477,fill='green') # sevres babylone
canvas.create_oval(392,477,399,484,fill='red')
canvas.create_oval(416,457,423,464,fill='magenta') # Odeon
canvas.create_oval(442,471,449,478,fill='red')
canvas.create_oval(460,504,467,511,fill='brown')
canvas.create_oval(471,517,478,524,fill='brown')
canvas.create_oval(494,511,501,518,fill='pink') # jussieu
canvas.create_oval(520,532,527,539,fill='orange') # Gare d'austerlitz

"""ligne 11 Chatelet -> Mairie des lilas"""

canvas.create_oval(460,390,467,397,fill='red') # Chatelet
canvas.create_oval(522,397,529,404,fill='red') # Hotel de ville
canvas.create_oval(520,370,527,377,fill='brown')
canvas.create_oval(525,347,532,357,fill='brown') # art et metier
canvas.create_oval(545,333,552,340,fill='brown') # temple
canvas.create_oval(571,318,582,328,fill='green') # Republique
canvas.create_oval(637,283,644,290,fill='brown') 
canvas.create_oval(664,269,671,276,fill='red') # Beleville
canvas.create_oval(690,254,697,261,fill='brown')
canvas.create_oval(714,240,721,247,fill='brown')
canvas.create_oval(738,224,745,231,fill='brown') # place des fetes
canvas.create_oval(758,215,765,222,fill='brown')
canvas.create_oval(776,204,783,211,fill='brown') # porte des lilas
canvas.create_oval(800,191,807,198,fill='brown')

"""ligne 12 mairie d'issy -> aubervilliers"""

canvas.create_oval(628,62,635,69,fill='green')
canvas.create_oval(612,97,619,104,fill='green')
canvas.create_oval(594,131,601,138,fill='green')
canvas.create_oval(528,116,535,123,fill='green') # marcadet poissonier
canvas.create_oval(489,109,496,116,fill='green')
canvas.create_oval(447,107,454,114,fill='green')
canvas.create_oval(413,132,420,139,fill='green')
canvas.create_oval(416,156,423,163,fill='red') # pigale
canvas.create_oval(424,189,431,196,fill='green')
canvas.create_oval(430,220,437,227,fill='green')
canvas.create_oval(400,236,407,243,fill='red')
canvas.create_oval(337,273,347,281,fill='red') # saint lazare
canvas.create_oval(340,338,347,345,fill='red') # madeleine
canvas.create_oval(332,370,339,377,fill='green') # concorde
canvas.create_oval(337,425,344,432,fill='green')
canvas.create_oval(342,440,349,447,fill='green')
canvas.create_oval(349,454,356,461,fill='red')
canvas.create_oval(361,470,368,477,fill='green') # sevres babylone
canvas.create_oval(351,500,358,507,fill='green')
canvas.create_oval(331,523,338,530,fill='red')
canvas.create_oval(300,555,312,570,fill='green') # Montparnasse Bienvenue
canvas.create_oval(292,545,299,552,fill='green')
canvas.create_oval(279,536,286,543,fill='green') # pasteur
canvas.create_oval(256,548,263,555,fill='green') 
canvas.create_oval(239,560,246,567,fill='green')
canvas.create_oval(222,574,229,581,fill='green')
canvas.create_oval(205,586,212,593,fill='green') 
canvas.create_oval(189,600,196,607,fill='green')
canvas.create_oval(170,611,177,618,fill='green')

"""ligne 13 La fourche -> chatillon montrouge"""

canvas.create_oval(332,158,339,165,fill='cyan')
canvas.create_oval(347,181,354,188,fill='red') # Porte de clichy
canvas.create_oval(362,212,369,219,fill='cyan')
canvas.create_oval(337,273,347,281,fill='red') # saint lazare
canvas.create_oval(306,329,313,336,fill='red') # miromesnil
canvas.create_oval(296,364,303,371,fill='cyan') # champ elysee
canvas.create_oval(298,425,305,432,fill='cyan') # invalide
canvas.create_oval(303,442,310,449,fill='cyan')
canvas.create_oval(311,462,318,469,fill='cyan')
canvas.create_oval(321,478,328,485,fill='cyan') # duroc
canvas.create_oval(300,555,312,570,fill='green') # montparnasse
canvas.create_oval(290,578,297,585,fill='cyan') 
canvas.create_oval(278,591,285,598,fill='cyan')
canvas.create_oval(266,605,273,612,fill='cyan')
canvas.create_oval(253,620,260,627,fill='cyan')
canvas.create_oval(240,633,247,640,fill='cyan')
canvas.create_oval(229,647,236,654,fill='cyan')
canvas.create_oval(215,660,222,667,fill='cyan')

"""ligne 14  Saint lazare -> olympiade"""

canvas.create_oval(337,273,347,281,fill='red') # saint lazare
canvas.create_oval(340,338,347,345,fill='red') # madeleine
canvas.create_oval(370,349,377,356,fill='pink') # pyramide
canvas.create_oval(460,390,467,397,fill='red') # Chatelet
canvas.create_oval(598,440,604,455,fill='red') # Gare de lyon
canvas.create_oval(630,552,637,559,fill='green') # Bercy   
canvas.create_oval(655,578,662,585,fill='purple')
canvas.create_oval(638,605,645,612,fill='purple')
canvas.create_oval(614,622,621,629,fill='purple') 

canvas.pack()
fenetre.mainloop()'''
# Out:
# 'fenetre = Tk()\n\nphoto = PhotoImage(master=fenetre, file="cerclemetro.pgm")\n\ncanvas = Canvas(fenetre,width=869, height=720)\ncanvas.create_image(0, 0, anchor=NW, image=photo)\n\n"""ligne 1 la defense -> chateau de vincenne"""\n\ncanvas.create_oval(37,208,44,215,fill=\'red\')\ncanvas.create_oval(67,221,74,228,fill=\'red\')\ncanvas.create_oval(99,234,106,241,fill=\'red\')\ncanvas.create_oval(130,247,137,254,fill=\'red\')\ncanvas.create_oval(171,265,178,272,fill=\'red\')\ncanvas.create_oval(195,276,202,283,fill=\'red\')\ncanvas.create_oval(221,295,229,281,fill=\'red\') # charles de gaule etoile\ncanvas.create_oval(268,316,275,323,fill=\'red\')\ncanvas.create_oval(260,342,271,349,fill=\'red\') # Franklin D Roosevelt\ncanvas.create_oval(296,364,303,371,fill=\'red\') # champ elysee\ncanvas.create_oval(331,368,341,375,fill=\'red\') # concorde\ncanvas.create_oval(359,373,366,380,fill=\'red\')\ncanvas.create_oval(381,387,388,377,fill=\'red\') # Palais royal\ncanvas.create_oval(405,379,412
# ...

# %%
def simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,nombredestation,ta,cm, bio, tbio):
    L_del = []
    if (t%(24*3600)>3600 and t%(24*3600)<3600*6):
        bio2=100000
        bio3=0
    elif ((t%(24*3600)>3600*7 and t%(24*3600)<3600*9) or (t%(24*3600)>3600*16 and t%(24*3600)<3600*20)):
        bio2 = 200
        bio3= 8
    else :
        bio2 = 300
        bio3 = 3
    for i in range(bio3):
        a=np.random.choice(len(L_gare) - 1)
        L_gare[a][0]+=1
        L_dest_gare[a].append(np.random.choice(len(L_gare) - a - 1)+ a + 1)
        
    if (t - bio < 0 or t - bio > tbio):
        if(t%bio2==0):
            L_train.append([t,0])
            L_dest_train.append([])

        for i in range(len(L_train)):
            if((t-L_train[i][0])%ta==0): # test pour savoir si un metro est arrive a une station
                if ((t-L_train[i][0])//ta<nombredestation):
                    x=(t-L_train[i][0])//ta   # x correspond a l'indice de la station ou un train se situe
                    c = -1
                    for k in range(len(L_train)): 
                        if (L_train[k][0] == t - ta * x): # test pour savoir si il s'agit du train qui est a quai
                            c = k # c correspond a l'indice du train qui est a quai
                            ns=len(L_dest_train[c])
                            m=0
                            while(m<ns): #les passagers arrivé a destination sortent du train
                                if(L_dest_train[c][m]==x):
                                    del L_dest_train[c][m]
                                    L_train[c][1]-=1 
                                    ns-=1
                                m+=1
                            if (L_train[c][0] == t - ta * (nombredestation - 1)):#test si on est en terminus (tous le monde descend)

                                L_train[c][1] = 0
                                L_dest_train[c] = []
                                L_del.append(c)
                            if(L_gare[x][0]<cm-L_train[i][1]): # les passagers rentrent dans le train quand celui ci est a quai
                                L_train[i][1]=L_train[i][1]+L_gare[x][0]
                                for j in range(len(L_dest_gare[x])):
                                    L_dest_train[c].append(L_dest_gare[x][j])
                                L_dest_gare[x]=[]
                                L_gare[x][0]=0
                            else:
                                L_gare[x][0]=L_gare[x][0]-(cm-L_train[i][1])
                                for j in range(cm-L_train[i][1]):
                                    L_dest_train[c].append(L_dest_gare[x][0])
                                    del L_dest_gare[x][0]
                                L_train[i][1]=cm
        for i in range(len(L_del)):
            del L_dest_train[L_del[-i]]
            del L_train[L_del[-i]]

# %%
import time


L_train0=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare0=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare0.append([0])
L_dest_train0=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare0=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare0.append([])

L_train1=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare1=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare1.append([0])
L_dest_train1=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare1=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare1.append([])

L_train2=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare2=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare2.append([0])
L_dest_train2=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare2=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare2.append([])
 
L_train3=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare3=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare3.append([0])
L_dest_train3=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare3=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare3.append([])
""""""
L_train4=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare4=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare4.append([0])
L_dest_train4=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare4=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare4.append([])

L_train5=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare5=[]# liste du nombre de personne dans toutes les gares
for i in range(25):
    L_gare5.append([0])
L_dest_train5=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare5=[] # liste de liste de la destination de chaque personne dans une station
for i in range(25):
    L_dest_gare5.append([])

L_train6=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare6=[]# liste du nombre de personne dans toutes les gares
for i in range(4):
    L_gare6.append([0])
L_dest_train6=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare6=[] # liste de liste de la destination de chaque personne dans une station
for i in range(4):
    L_dest_gare6.append([])
 
L_train7=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare7=[]# liste du nombre de personne dans toutes les gares
for i in range(4):
    L_gare7.append([0])
L_dest_train7=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare7=[] # liste de liste de la destination de chaque personne dans une station
for i in range(4):
    L_dest_gare7.append([])

L_train8=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare8=[]# liste du nombre de personne dans toutes les gares
for i in range(27):
    L_gare8.append([0])
L_dest_train8=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare8=[] # liste de liste de la destination de chaque personne dans une station
for i in range(27):
    L_dest_gare8.append([])

L_train9=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare9=[]# liste du nombre de personne dans toutes les gares
for i in range(27):
    L_gare9.append([0])
L_dest_train9=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare9=[] # liste de liste de la destination de chaque personne dans une station
for i in range(27):
    L_dest_gare9.append([])

L_train10=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare10=[]# liste du nombre de personne dans toutes les gares
for i in range(22):
    L_gare10.append([0])
L_dest_train10=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare10=[] # liste de liste de la destination de chaque personne dans une station
for i in range(22):
    L_dest_gare10.append([])
 
L_train11=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare11=[]# liste du nombre de personne dans toutes les gares
for i in range(22):
    L_gare11.append([0])
L_dest_train11=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare11=[] # liste de liste de la destination de chaque personne dans une station
for i in range(22):
    L_dest_gare11.append([])


L_couleur0=[]
for i in range(25):
    L_couleur0.append([])
L_couleur1=[]
for i in range(25):
    L_couleur1.append([])
L_couleur2=[]
for i in range(25):
    L_couleur2.append([])
L_couleur3=[]
for i in range(4):
    L_couleur3.append([])
L_couleur4=[]
for i in range(27):
    L_couleur4.append([])
L_couleur5=[]
for i in range(22):
    L_couleur5.append([])

accident = 90000
tacc = 0
nbstep=24*3600
fenetre = Tk()

photo = PhotoImage(master=fenetre, file="cerclemetro.pgm")

canvas = Canvas(fenetre,width=869, height=720)
canvas.create_image(0, 0, anchor=NW, image=photo)

"""ligne 1 la defense -> chateau de vincenne"""

station0=canvas.create_oval(37,208,44,215,fill='red')
station1=canvas.create_oval(67,221,74,228,fill='red')
station2=canvas.create_oval(99,234,106,241,fill='red')
station3=canvas.create_oval(130,247,137,254,fill='red')
station4=canvas.create_oval(171,265,178,272,fill='red')
station5=canvas.create_oval(195,276,202,283,fill='red')
station6=canvas.create_oval(221,295,229,281,fill='red') # charles de gaule etoile
station7=canvas.create_oval(268,316,275,323,fill='red')
station8=canvas.create_oval(260,342,271,349,fill='red') # Franklin D Roosevelt
station9=canvas.create_oval(296,364,303,371,fill='red') # champ elysee
station10=canvas.create_oval(331,368,341,375,fill='red') # concorde
station11=canvas.create_oval(359,373,366,380,fill='red')
station12=canvas.create_oval(381,387,388,377,fill='red') # Palais royal
station13=canvas.create_oval(405,379,412,386,fill='red')
station14=canvas.create_oval(460,390,467,397,fill='red') # Chatelet
station15=canvas.create_oval(522,397,529,404,fill='red') # Hotel de ville
station16=canvas.create_oval(545,400,552,407,fill='red')
station17=canvas.create_oval(590,404,597,413,fill='red') # Bastille
station18=canvas.create_oval(598,440,604,455,fill='red') # Gare de lyon
station19=canvas.create_oval(627,462,634,469,fill='red') # Reuilly diderot
station20=canvas.create_oval(701,484,708,502,fill='red') # Nation
station21=canvas.create_oval(725,505,732,512,fill='red')
station22=canvas.create_oval(756,518,763,525,fill='red')
station23=canvas.create_oval(787,531,794,538,fill='red')
station24=canvas.create_oval(818,544,825,551,fill='red')

"""ligne 2 Nation -> Porte dauphine"""

station25=canvas.create_oval(701,484,708,502,fill='red') # Nation
station26=canvas.create_oval(687,450,694,457,fill='red')
station27=canvas.create_oval(695,408,702,415,fill='red')
station28=canvas.create_oval(695,364,702,371,fill='red')
station29=canvas.create_oval(685,321,692,328,fill='red') # Pere Lachaise
station30=canvas.create_oval(680,303,687,310,fill='red')
station31=canvas.create_oval(673,286,680,293,fill='red')
station32=canvas.create_oval(664,269,671,276,fill='red') # Beleville
station33=canvas.create_oval(650,250,657,257,fill='red')
station34=canvas.create_oval(622,217,629,224,fill='red') # Jaures
station35=canvas.create_oval(610,200,617,207,fill='pink') # Stalingrad
station36=canvas.create_oval(569,179,576,186,fill='red')
station37=canvas.create_oval(536,161,543,168,fill='blue') # Barbes
station38=canvas.create_oval(476,154,483,161,fill='red')
station39=canvas.create_oval(416,156,423,163,fill='red') # pigale
station40=canvas.create_oval(382,167,389,174,fill='red')
station41=canvas.create_oval(347,181,354,188,fill='red') # Porte de clichy
station42=canvas.create_oval(315,201,322,208,fill='red')
station43=canvas.create_oval(288,228,295,235,fill='red') # Villiers
station44=canvas.create_oval(273,244,280,251,fill='red') 
station45=canvas.create_oval(260,261,267,268,fill='red')
station46=canvas.create_oval(251,278,258,285,fill='red')
station47=canvas.create_oval(221,295,229,281,fill='red') # Charles de gaulle etoile
station48=canvas.create_oval(189,327,196,334,fill='red')
station49=canvas.create_oval(184,348,191,355,fill='red')


station50=canvas.create_oval(837,277,844,284,fill='#cdcd0d')
station51=canvas.create_oval(811,284,818,291,fill='#cdcd0d')
station52=canvas.create_oval(770,293,777,304,fill='#cdcd0d') # Gambetta
station53=canvas.create_oval(685,321,692,328,fill='#cdcd0d') # Pere Lachaise
station54=canvas.create_oval(647,316,654,323,fill='#cdcd0d')
station55=canvas.create_oval(637,294,644,301,fill='#cdcd0d')
station56=canvas.create_oval(571,318,582,328,fill='green') # Republique
station57=canvas.create_oval(545,333,552,340,fill='brown') # Temple
station58=canvas.create_oval(525,347,532,357,fill='brown') # art et metier
station59=canvas.create_oval(485,330,492,337,fill='magenta') # reaumur sebastopol
station60=canvas.create_oval(461,325,468,332,fill='#cdcd0d')
station61=canvas.create_oval(440,332,447,339,fill='#cdcd0d')
station62=canvas.create_oval(423,342,430,349,fill='#cdcd0d')
station63=canvas.create_oval(389,321,396,328,fill='pink') # opera
station64=canvas.create_oval(365,298,372,305,fill='#cdcd0d') # Havre caumartin
station65=canvas.create_oval(337,273,347,281,fill='red') # saint lazare
station66=canvas.create_oval(312,250,319,257,fill='#cdcd0d')
station67=canvas.create_oval(288,228,295,235,fill='#cdcd0d') # villiers
station68=canvas.create_oval(268,209,275,216,fill='#cdcd0d')
station69=canvas.create_oval(251,193,258,200,fill='#cdcd0d')
station70=canvas.create_oval(231,172,238,179,fill='#cdcd0d')
station71=canvas.create_oval(214,158,221,165,fill='#cdcd0d')
station72=canvas.create_oval(201,146,208,153,fill='#cdcd0d')
station73=canvas.create_oval(188,134,195,141,fill='#cdcd0d')
station74=canvas.create_oval(174,120,181,127,fill='#cdcd0d')

station75=canvas.create_oval(770,293,777,304,fill='cyan') # Gambetta
station76=canvas.create_oval(804,261,811,268,fill='cyan')
station77=canvas.create_oval(793,232,800,239,fill='red')
station78=canvas.create_oval(776,204,783,211,fill='brown') # porte des lilas

station79=canvas.create_oval(329,699,336,706,fill='magenta')
station80=canvas.create_oval(338,675,345,682,fill='magenta')
station81=canvas.create_oval(348,652,355,659,fill='magenta')
station82=canvas.create_oval(358,629,365,636,fill='magenta')
station83=canvas.create_oval(369,606,379,613,fill='green') # denfert rochereau
station84=canvas.create_oval(350,595,357,602,fill='red') # Ragdal
station85=canvas.create_oval(334,579,341,586,fill='red')
station86=canvas.create_oval(300,555,312,570,fill='green') # Montparnasse Bienvenue
station87=canvas.create_oval(353,510,360,517,fill='magenta')
station88=canvas.create_oval(372,492,379,499,fill='magenta')
station89=canvas.create_oval(392,466,399,473,fill='magenta')
station90=canvas.create_oval(416,457,423,464,fill='magenta') # Odeon        
station91=canvas.create_oval(434,451,441,458,fill='magenta')
station92=canvas.create_oval(443,428,450,435,fill='magenta')
station93=canvas.create_oval(460,390,467,397,fill='red') # Chatelet
station94=canvas.create_oval(466,375,473,382,fill='magenta') # Les Halles
station95=canvas.create_oval(475,353,482,360,fill='magenta')
station96=canvas.create_oval(485,330,492,337,fill='magenta') # reaumur sebastopol
station97=canvas.create_oval(499,298,506,305,fill='magenta') # starsbourg saint denis
station98=canvas.create_oval(509,273,516,280,fill='magenta') 
station99=canvas.create_oval(530,215,541,222,fill='pink') # Gare de l'est
station100=canvas.create_oval(545,189,559,198,fill='magenta') # Gare du nord
station101=canvas.create_oval(536,161,543,168,fill='blue') # Barbes
station102=canvas.create_oval(525,137,532,144,fill='magenta')
station103=canvas.create_oval(528,116,535,123,fill='green') # marcadet poissonier
station104=canvas.create_oval(536,92,543,99,fill='magenta')
station105=canvas.create_oval(540,70,547,77,fill='magenta')

station106=canvas.create_oval(750,122,757,129,fill='orange')
station107= canvas.create_oval(735,140,742,147,fill='orange')
station108=canvas.create_oval(718,155,725,162,fill='orange')
station109= canvas.create_oval(700,171,707,178,fill='orange')
station110= canvas.create_oval(683,186,690,193,fill='orange')
station111= canvas.create_oval(667,202,674,209,fill='orange')
station112= canvas.create_oval(650,218,657,225,fill='orange')
station113=canvas.create_oval(622,217,629,224,fill='orange') # Jaures
station114=canvas.create_oval(610,200,617,207,fill='pink') # Stalingrad
station115=canvas.create_oval(545,189,559,198,fill='orange') # Gare du nord
station116=canvas.create_oval(530,215,541,222,fill='pink') # Gare de l'est
station117=canvas.create_oval(542,284,549,291,fill='orange')
station118=canvas.create_oval(571,318,582,328,fill='green') # Republique
station119=canvas.create_oval(585,342,592,349,fill='green') # Oberkampf
station120=canvas.create_oval(589,361,596,368,fill='orange')
station121=canvas.create_oval(591,379,598,386,fill='orange')
station122=canvas.create_oval(590,404,597,413,fill='red') # Bastille
station123=canvas.create_oval(540,581,547,588,fill='orange')
station124=canvas.create_oval(520,532,527,539,fill='orange') # Gare d'austerlitz
station125=canvas.create_oval(542,487,549,494,fill='orange')
station126=canvas.create_oval(574,454,581,461,fill='orange')
station127=canvas.create_oval(523,612,530,622,fill='blue') # Place d'italie



t=0
y=0
for i in range(nbstep):
    simulation(L_gare0,L_train0,L_dest_gare0,L_dest_train0,t,25,150,700, accident, tacc)
    simulation(L_gare1,L_train1,L_dest_gare1,L_dest_train1,t,25,150,700, accident, tacc)
    simulation(L_gare2,L_train2,L_dest_gare2,L_dest_train2,t,25,150,700, accident, tacc)
    simulation(L_gare3,L_train3,L_dest_gare3,L_dest_train3,t,25,150,700, accident, tacc)
    simulation(L_gare4,L_train4,L_dest_gare4,L_dest_train4,t,25,150,700, accident, tacc)
    simulation(L_gare5,L_train5,L_dest_gare5,L_dest_train5,t,25,150,700, accident, tacc)
    simulation(L_gare6,L_train6,L_dest_gare6,L_dest_train6,t,4,150,700, accident, tacc)
    simulation(L_gare7,L_train7,L_dest_gare7,L_dest_train7,t,4,150,700, accident, tacc)
    simulation(L_gare8,L_train8,L_dest_gare8,L_dest_train8,t,27,150,700, accident, tacc)
    simulation(L_gare9,L_train9,L_dest_gare9,L_dest_train9,t,27,150,700, accident, tacc)
    simulation(L_gare10,L_train10,L_dest_gare10,L_dest_train10,t,22,150,700, accident, tacc)
    simulation(L_gare11,L_train11,L_dest_gare11,L_dest_train11,t,22,150,700, accident, tacc)
    y+=1
    t+=1
    if (i%(10)==0):
        for j in range(len(L_gare0)):
            if (L_gare0[j][0]+L_gare1[len(L_gare0)-j-1][0]<10):
                L_couleur0[j]='#1E90FF'
            elif (L_gare0[j][0]+L_gare1[len(L_gare0)-j-1][0]<20):
                L_couleur0[j]='cyan'
            elif (L_gare0[j][0]+L_gare1[len(L_gare0)-j-1][0]<30):
                L_couleur0[j]='#00FF00'
            elif (L_gare0[j][0]+L_gare1[len(L_gare0)-j-1][0]<40):
                L_couleur0[j]='yellow'
            elif (L_gare0[j][0]+L_gare1[len(L_gare0)-j-1][0]<50):
                L_couleur0[j]='#FFA500'
            else:
                L_couleur0[j]='red'
        for j in range(len(L_gare2)):
            if (L_gare2[j][0]+L_gare3[len(L_gare3)-j-1][0]<10):
                L_couleur1[j]='#1E90FF'
            elif (L_gare2[j][0]+L_gare3[len(L_gare3)-j-1][0]<20):
                L_couleur1[j]='cyan'
            elif (L_gare2[j][0]+L_gare3[len(L_gare3)-j-1][0]<30):
                L_couleur1[j]='#00FF00'
            elif (L_gare2[j][0]+L_gare3[len(L_gare3)-j-1][0]<40):
                L_couleur1[j]='yellow'
            elif (L_gare2[j][0]+L_gare3[len(L_gare3)-j-1][0]<50):
                L_couleur1[j]='#FFA500'
            else:
                L_couleur1[j]='red'
        for j in range(len(L_gare4)):
            if (L_gare4[j][0]+L_gare5[len(L_gare5)-j-1][0]<10):
                L_couleur2[j]='#1E90FF'
            elif (L_gare4[j][0]+L_gare5[len(L_gare5)-j-1][0]<20):
                L_couleur2[j]='cyan'
            elif (L_gare4[j][0]+L_gare5[len(L_gare5)-j-1][0]<30):
                L_couleur2[j]='#00FF00'
            elif (L_gare4[j][0]+L_gare5[len(L_gare5)-j-1][0]<40):
                L_couleur2[j]='yellow'
            elif (L_gare4[j][0]+L_gare5[len(L_gare5)-j-1][0]<50):
                L_couleur2[j]='#FFA500'
            else:
                L_couleur2[j]='red'
        for j in range(len(L_gare6)):
            if (L_gare6[j][0]+L_gare7[len(L_gare7)-j-1][0]<10):
                L_couleur3[j]='#1E90FF'
            elif (L_gare6[j][0]+L_gare7[len(L_gare7)-j-1][0]<20):
                L_couleur3[j]='cyan'
            elif (L_gare6[j][0]+L_gare7[len(L_gare7)-j-1][0]<30):
                L_couleur3[j]='#00FF00'
            elif (L_gare6[j][0]+L_gare7[len(L_gare7)-j-1][0]<40):
                L_couleur3[j]='yellow'
            elif (L_gare6[j][0]+L_gare7[len(L_gare7)-j-1][0]<50):
                L_couleur3[j]='#FFA500'
            else:
                L_couleur3[j]='red'
        for j in range(len(L_gare8)):
            if (L_gare8[j][0]+L_gare9[len(L_gare9)-j-1][0]<10):
                L_couleur4[j]='#1E90FF'
            elif (L_gare8[j][0]+L_gare9[len(L_gare9)-j-1][0]<20):
                L_couleur4[j]='cyan'
            elif (L_gare8[j][0]+L_gare9[len(L_gare9)-j-1][0]<30):
                L_couleur4[j]='#00FF00'
            elif (L_gare8[j][0]+L_gare9[len(L_gare9)-j-1][0]<40):
                L_couleur4[j]='yellow'
            elif (L_gare8[j][0]+L_gare9[len(L_gare9)-j-1][0]<50):
                L_couleur4[j]='#FFA500'
            else:
                L_couleur4[j]='red'
        for j in range(len(L_gare10)):
            if (L_gare10[j][0]+L_gare11[len(L_gare10)-j-1][0]<10):
                L_couleur5[j]='#1E90FF'
            elif (L_gare10[j][0]+L_gare11[len(L_gare10)-j-1][0]<20):
                L_couleur5[j]='cyan'
            elif (L_gare10[j][0]+L_gare11[len(L_gare10)-j-1][0]<30):
                L_couleur5[j]='#00FF00'
            elif (L_gare10[j][0]+L_gare11[len(L_gare10)-j-1][0]<40):
                L_couleur5[j]='yellow'
            elif (L_gare10[j][0]+L_gare11[len(L_gare10)-j-1][0]<50):
                L_couleur5[j]='#FFA500'
            else:
                L_couleur5[j]='red'
    canvas.delete(station0)
    station0=canvas.create_oval(37,208,44,215,fill=L_couleur0[0])
    canvas.delete(station1)
    station1=canvas.create_oval(67,221,74,228,fill=L_couleur0[1])
    canvas.delete(station2)
    station2=canvas.create_oval(99,234,106,241,fill=L_couleur0[2])
    canvas.delete(station3)
    station3=canvas.create_oval(130,247,137,254,fill=L_couleur0[3])
    canvas.delete(station4)
    station4=canvas.create_oval(171,265,178,272,fill=L_couleur0[4])
    canvas.delete(station5)
    station5=canvas.create_oval(195,276,202,283,fill=L_couleur0[5])
    canvas.delete(station6)
    station6=canvas.create_oval(221,295,229,281,fill=L_couleur0[6]) # charles de gaule etoile
    canvas.delete(station7)
    station7=canvas.create_oval(268,316,275,323,fill=L_couleur0[7])
    canvas.delete(station8)
    station8=canvas.create_oval(260,342,271,349,fill=L_couleur0[8]) # Franklin D Roosevelt
    canvas.delete(station9)
    station9=canvas.create_oval(296,364,303,371,fill=L_couleur0[9]) # champ elysee
    canvas.delete(station10)
    station10=canvas.create_oval(331,368,341,375,fill=L_couleur0[10]) # concorde
    canvas.delete(station11)
    station11=canvas.create_oval(359,373,366,380,fill=L_couleur0[11])
    canvas.delete(station12)
    station12=canvas.create_oval(381,387,388,377,fill=L_couleur0[12]) # Palais royal
    canvas.delete(station13)
    station13=canvas.create_oval(405,379,412,386,fill=L_couleur0[13])
    canvas.delete(station14)
    station14=canvas.create_oval(460,390,467,397,fill=L_couleur0[14]) # Chatelet
    canvas.delete(station15)
    station15=canvas.create_oval(522,397,529,404,fill=L_couleur0[15]) # Hotel de ville
    canvas.delete(station16)
    station16=canvas.create_oval(545,400,552,407,fill=L_couleur0[16])
    canvas.delete(station17)
    station17=canvas.create_oval(590,404,597,413,fill=L_couleur0[17]) # Bastille
    canvas.delete(station18)
    station18=canvas.create_oval(598,440,604,455,fill=L_couleur0[18]) # Gare de lyon
    canvas.delete(station19)
    station19=canvas.create_oval(627,462,634,469,fill=L_couleur0[19]) # Reuilly diderot
    canvas.delete(station20)
    station20=canvas.create_oval(701,484,708,502,fill=L_couleur0[20]) # Nation
    canvas.delete(station21)
    station21=canvas.create_oval(725,505,732,512,fill=L_couleur0[21])
    canvas.delete(station22)
    station22=canvas.create_oval(756,518,763,525,fill=L_couleur0[22])
    canvas.delete(station23)
    station23=canvas.create_oval(787,531,794,538,fill=L_couleur0[23])
    canvas.delete(station24)
    station24=canvas.create_oval(818,544,825,551,fill=L_couleur0[24])
    canvas.delete(station25)
    station25=canvas.create_oval(701,484,708,502,fill=L_couleur1[0]) # Nation
    canvas.delete(station26)
    station26=canvas.create_oval(687,450,694,457,fill=L_couleur1[1])
    canvas.delete(station27)
    station27=canvas.create_oval(695,408,702,415,fill=L_couleur1[2])
    canvas.delete(station28)
    station28=canvas.create_oval(695,364,702,371,fill=L_couleur1[3])
    canvas.delete(station29)
    station29=canvas.create_oval(685,321,692,328,fill=L_couleur1[4]) # Pere Lachaise
    canvas.delete(station30)
    station30=canvas.create_oval(680,303,687,310,fill=L_couleur1[5])
    canvas.delete(station31)
    station31=canvas.create_oval(673,286,680,293,fill=L_couleur1[6])
    canvas.delete(station32)
    station32=canvas.create_oval(664,269,671,276,fill=L_couleur1[7]) # Beleville
    canvas.delete(station33)
    station33=canvas.create_oval(650,250,657,257,fill=L_couleur1[8])
    canvas.delete(station34)
    station34=canvas.create_oval(622,217,629,224,fill=L_couleur1[9]) # Jaures
    canvas.delete(station35)
    station35=canvas.create_oval(610,200,617,207,fill=L_couleur1[10]) # Stalingrad
    canvas.delete(station36)
    station36=canvas.create_oval(569,179,576,186,fill=L_couleur1[11])
    canvas.delete(station37)
    station37=canvas.create_oval(536,161,543,168,fill=L_couleur1[12]) # Barbes
    canvas.delete(station38)
    station38=canvas.create_oval(476,154,483,161,fill=L_couleur1[13])
    canvas.delete(station39)
    station39=canvas.create_oval(416,156,423,163,fill=L_couleur1[14]) # pigale
    canvas.delete(station40)
    station40=canvas.create_oval(382,167,389,174,fill=L_couleur1[15])
    canvas.delete(station41)
    station41=canvas.create_oval(347,181,354,188,fill=L_couleur1[16]) # Porte de clichy
    canvas.delete(station42)
    station42=canvas.create_oval(315,201,322,208,fill=L_couleur1[17])
    canvas.delete(station43)
    station43=canvas.create_oval(288,228,295,235,fill=L_couleur1[18]) # Villiers
    canvas.delete(station44)
    station44=canvas.create_oval(273,244,280,251,fill=L_couleur1[19]) 
    canvas.delete(station45)
    station45=canvas.create_oval(260,261,267,268,fill=L_couleur1[20])
    canvas.delete(station46)
    station46=canvas.create_oval(251,278,258,285,fill=L_couleur1[21])
    canvas.delete(station47)
    station47=canvas.create_oval(221,295,229,281,fill=L_couleur1[22]) # Charles de gaulle etoile
    canvas.delete(station48)
    station48=canvas.create_oval(189,327,196,334,fill=L_couleur1[23])
    canvas.delete(station49)
    station49=canvas.create_oval(184,348,191,355,fill=L_couleur1[24])
    canvas.delete(station50)
    canvas.delete(station51)
    canvas.delete(station52)
    canvas.delete(station53)
    canvas.delete(station54)
    canvas.delete(station55)
    canvas.delete(station56)
    canvas.delete(station57)
    canvas.delete(station58)
    canvas.delete(station59)
    canvas.delete(station60)
    canvas.delete(station61)
    canvas.delete(station62)
    canvas.delete(station63)
    canvas.delete(station64)
    canvas.delete(station65)
    canvas.delete(station66)
    canvas.delete(station67)
    canvas.delete(station68)
    canvas.delete(station69)
    canvas.delete(station70)
    canvas.delete(station71)
    canvas.delete(station72)
    canvas.delete(station73)
    canvas.delete(station74)
    canvas.delete(station75)
    canvas.delete(station76)
    canvas.delete(station77)
    canvas.delete(station78)
    canvas.delete(station79)
    canvas.delete(station80)
    canvas.delete(station81)
    canvas.delete(station82)
    canvas.delete(station83)
    canvas.delete(station84)
    canvas.delete(station85)
    canvas.delete(station86)
    canvas.delete(station87)
    canvas.delete(station88)
    canvas.delete(station89)
    canvas.delete(station90)
    canvas.delete(station91)
    canvas.delete(station92)
    canvas.delete(station93)
    canvas.delete(station94)
    canvas.delete(station95)
    canvas.delete(station96)
    canvas.delete(station97)
    canvas.delete(station98)
    canvas.delete(station99)
    canvas.delete(station100)
    canvas.delete(station101)
    canvas.delete(station102)
    canvas.delete(station103)
    canvas.delete(station104)
    canvas.delete(station105)
    canvas.delete(station106)
    canvas.delete(station107)
    canvas.delete(station108)
    canvas.delete(station109)
    canvas.delete(station110)
    canvas.delete(station111)
    canvas.delete(station112)
    canvas.delete(station113)
    canvas.delete(station114)
    canvas.delete(station115)
    canvas.delete(station116)
    canvas.delete(station117)
    canvas.delete(station118)
    canvas.delete(station119)
    canvas.delete(station120)
    canvas.delete(station121)
    canvas.delete(station122)
    canvas.delete(station123)
    canvas.delete(station124)
    canvas.delete(station125)
    canvas.delete(station126)
    canvas.delete(station127)

    station50=canvas.create_oval(837,277,844,284,fill=L_couleur2[0])
    station51=canvas.create_oval(811,284,818,291,fill=L_couleur2[1])
    station52=canvas.create_oval(770,293,777,304,fill=L_couleur2[2]) # Gambetta
    station53=canvas.create_oval(685,321,692,328,fill=L_couleur2[3]) # Pere Lachaise
    station54=canvas.create_oval(647,316,654,323,fill=L_couleur2[4])
    station55=canvas.create_oval(637,294,644,301,fill=L_couleur2[5])
    station56=canvas.create_oval(571,318,582,328,fill=L_couleur2[6]) # Republique
    station57=canvas.create_oval(545,333,552,340,fill=L_couleur2[7]) # Temple
    station58=canvas.create_oval(525,347,532,357,fill=L_couleur2[8]) # art et metier
    station59=canvas.create_oval(485,330,492,337,fill=L_couleur2[9]) # reaumur sebastopol
    station60=canvas.create_oval(461,325,468,332,fill=L_couleur2[10])
    station61=canvas.create_oval(440,332,447,339,fill=L_couleur2[11])
    station62=canvas.create_oval(423,342,430,349,fill=L_couleur2[12])
    station63=canvas.create_oval(389,321,396,328,fill=L_couleur2[13]) # opera
    station64=canvas.create_oval(365,298,372,305,fill=L_couleur2[14]) # Havre caumartin
    station65=canvas.create_oval(337,273,347,281,fill=L_couleur2[15]) # saint lazare
    station66=canvas.create_oval(312,250,319,257,fill=L_couleur2[16])
    station67=canvas.create_oval(288,228,295,235,fill=L_couleur2[17]) # villiers
    station68=canvas.create_oval(268,209,275,216,fill=L_couleur2[18])
    station69=canvas.create_oval(251,193,258,200,fill=L_couleur2[19])
    station70=canvas.create_oval(231,172,238,179,fill=L_couleur2[20])
    station71=canvas.create_oval(214,158,221,165,fill=L_couleur2[21])
    station72=canvas.create_oval(201,146,208,153,fill=L_couleur2[22])
    station73=canvas.create_oval(188,134,195,141,fill=L_couleur2[23])
    station74=canvas.create_oval(174,120,181,127,fill=L_couleur2[24])

    station75=canvas.create_oval(770,293,777,304,fill=L_couleur3[0]) # Gambetta
    station76=canvas.create_oval(804,261,811,268,fill=L_couleur3[1])
    station77=canvas.create_oval(793,232,800,239,fill=L_couleur3[2])
    station78=canvas.create_oval(776,204,783,211,fill=L_couleur3[3]) # porte des lilas
    
    station79=canvas.create_oval(329,699,336,706,fill=L_couleur4[0])
    station80=canvas.create_oval(338,675,345,682,fill=L_couleur4[1])
    station81=canvas.create_oval(348,652,355,659,fill=L_couleur4[2])
    station82=canvas.create_oval(358,629,365,636,fill=L_couleur4[3])
    station83=canvas.create_oval(369,606,379,613,fill=L_couleur4[4])# denfert rochereau
    station84=canvas.create_oval(350,595,357,602,fill=L_couleur4[5])# Ragdal
    station85=canvas.create_oval(334,579,341,586,fill=L_couleur4[6])
    station86=canvas.create_oval(300,555,312,570,fill=L_couleur4[7])# Montparnasse Bienvenue
    station87=canvas.create_oval(353,510,360,517,fill=L_couleur4[8])
    station88=canvas.create_oval(372,492,379,499,fill=L_couleur4[9])
    station89=canvas.create_oval(392,466,399,473,fill=L_couleur4[10])
    station90=canvas.create_oval(416,457,423,464,fill=L_couleur4[11])# Odeon        
    station91=canvas.create_oval(434,451,441,458,fill=L_couleur4[12])
    station92=canvas.create_oval(443,428,450,435,fill=L_couleur4[13])
    station93=canvas.create_oval(460,390,467,397,fill=L_couleur4[14])# Chatelet
    station94=canvas.create_oval(466,375,473,382,fill=L_couleur4[15])# Les Halles
    station95=canvas.create_oval(475,353,482,360,fill=L_couleur4[16])
    station96=canvas.create_oval(485,330,492,337,fill=L_couleur4[17])# reaumur sebastopol
    station97=canvas.create_oval(499,298,506,305,fill=L_couleur4[18])# starsbourg saint denis
    station98=canvas.create_oval(509,273,516,280,fill=L_couleur4[19])
    station99=canvas.create_oval(530,215,541,222,fill=L_couleur4[20])# Gare de l'est
    station100=canvas.create_oval(545,189,559,198,fill=L_couleur4[21])# Gare du nord
    station101=canvas.create_oval(536,161,543,168,fill=L_couleur4[22])# Barbes
    station102=canvas.create_oval(525,137,532,144,fill=L_couleur4[23])
    station103=canvas.create_oval(528,116,535,123,fill=L_couleur4[24])# marcadet poissonier
    station104=canvas.create_oval(536,92,543,99,fill=L_couleur4[25])
    station105=canvas.create_oval(540,70,547,77,fill=L_couleur4[26])

    station106=canvas.create_oval(750,122,757,129,fill=L_couleur5[0])
    station107= canvas.create_oval(735,140,742,147,fill=L_couleur5[1])
    station108=canvas.create_oval(718,155,725,162,fill=L_couleur5[2])
    station109= canvas.create_oval(700,171,707,178,fill=L_couleur5[3])
    station110= canvas.create_oval(683,186,690,193,fill=L_couleur5[4])
    station111= canvas.create_oval(667,202,674,209,fill=L_couleur5[5])
    station112= canvas.create_oval(650,218,657,225,fill=L_couleur5[6])
    station113=canvas.create_oval(622,217,629,224,fill=L_couleur5[7]) # Jaures
    station114=canvas.create_oval(610,200,617,207,fill=L_couleur5[8]) # Stalingrad
    station115=canvas.create_oval(545,189,559,198,fill=L_couleur5[9]) # Gare du nord
    station116=canvas.create_oval(530,215,541,222,fill=L_couleur5[10]) # Gare de l'est
    station117=canvas.create_oval(542,284,549,291,fill=L_couleur5[11])
    station118=canvas.create_oval(571,318,582,328,fill=L_couleur5[12]) # Republique
    station119=canvas.create_oval(585,342,592,349,fill=L_couleur5[13]) # Oberkampf
    station120=canvas.create_oval(589,361,596,368,fill=L_couleur5[14])
    station121=canvas.create_oval(591,379,598,386,fill=L_couleur5[15])
    station122=canvas.create_oval(590,404,597,413,fill=L_couleur5[16]) # Bastille
    station123=canvas.create_oval(540,581,547,588,fill=L_couleur5[17])
    station124=canvas.create_oval(520,532,527,539,fill=L_couleur5[18]) # Gare d'austerlitz
    station125=canvas.create_oval(542,487,549,494,fill=L_couleur5[19])
    station126=canvas.create_oval(574,454,581,461,fill=L_couleur5[20])
    station127=canvas.create_oval(523,612,530,622,fill=L_couleur5[21]) # Place d'italie

    canvas.pack()
    #time.sleep(0.001)
    canvas.update()
fenetre.mainloop()
""" 
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
    
L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])"""
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-5-a011b68e1776> in <module>()
#     377             else:
#     378                 L_couleur5[j]='red'
# --> 379     canvas.delete(station0)
#     380     station0=canvas.create_oval(37,208,44,215,fill=L_couleur0[0])
#     381     canvas.delete(station1)
#
# ~\Anaconda3\lib\tkinter\__init__.py in delete(self, *args)
#    2506     def delete(self, *args):
#    2507         """Delete items identified by all tag or ids contained in ARGS."""
# -> 2508         self.tk.call((self._w, 'delete') + args)
#    2509     def dtag(self, *args):
#    2510         """Delete tag or id given as last arguments in ARGS from items
#
# TclError: invalid command name ".!canvas"
