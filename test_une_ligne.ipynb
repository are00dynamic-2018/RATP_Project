# %%
# %matplotlib inline

from pylab import *

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
#from LibMetroIti_NB import *

# %%
nombredestation=37

L_dest_train=[]
L_dest_gare=[]
for i in range(nombredestation):
    L_dest_gare.append([])
L_train=[]#[[temps ou le train pop,le nombre de personne dans le train]]
L_gare=[]
for i in range(nombredestation):
    L_gare.append([0])

    
    
def simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,ta,cm):
    bio=t
    for i in range(5):
        a=np.random.choice(len(L_gare))
        L_gare[a][0]+=1
        L_dest_gare[a].append(np.random.choice(len(L_gare)-a)+a)

    if(y%300==0):
        L_train.append([bio,0])
        L_dest_train.append([])
    
    for i in range(len(L_train)):
        if((t-L_train[i][0])%ta==0): # test pour savoir si un metro est arrive a une station
            x=(t-L_train[i][0])//ta   # x correspond a l'indice de la station ou un train se situe
            c = -1
            for k in range(len(L_train)): 
                if (L_train[k][0] == t - ta * x): # test pour savoir si il s'agit du train qui est a quai
                    c = k # c correspond a l'indice du train qui est a quai
            if (c!=-1): # test totalement inutile car on sait deja qu'un train est a quai
                for m in range(len(L_dest_train[c])): #les passagers arrivé a destination sortent du train
                    """if(L_dest_train[c][m]==x):
                        del L_dest_train[c][m]
                        L_train[c][1]-=1 
                        ici on a un out of range mais c'est pas utile de faire descendre les passager pr la simu donc osef"""
                if(L_gare[x][0]<cm-L_train[i][1]): # les passagers rentrent dans le train quand celui ci est a quai
                    L_train[i][1]=L_train[i][1]+L_gare[x][0]
                    for j in range(len(L_dest_gare[x])):
                        L_dest_train[c].append(L_dest_gare[x][j])
                    L_dest_gare[x]=[]
                    L_gare[x][0]=0
                else:
                    L_gare[x][0]=L_gare[x][0]-(cm-L_train[i][1])
                    for j in range(cm-L_train[i][1]):
                        L_dest_train[c].append(L_dest_gare[x][0])
                        del L_dest_gare[x][0]
                    L_train[i][1]=cm

# %%
""" test a faire : dans une journée on recupere les infos tout les quart d'heure (simu map) et on bloquera le reseau pendant 
3h afin de voir l'accumulation des passagers"""
nbstep = 5000
y=0
t=0
for i in range(nbstep):
    simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,150,7000)
    y+=1
    t+=1
print(L_dest_train)
print(L_dest_gare)
print(L_train)
print(L_gare)
# Out:
# [[10, 35, 30, 31, 20, 16, 9, 35, 9, 15, 4, 30, 15, 36, 19, 22, 21, 13, 33, 30, 7, 18, 19, 16, 3, 8, 3, 6, 15, 13, 8, 11, 30, 11, 33, 23, 8, 11, 7, 18, 21, 24, 6, 11, 2, 29, 19, 27, 33, 16, 2, 12, 11, 13, 11, 3, 9, 34, 31, 8, 19, 25, 2, 21, 12, 7, 34, 12, 23, 19, 12, 17, 20, 24, 31, 28, 15, 34, 24, 32, 3, 7, 20, 33, 30, 9, 6, 30, 16, 16, 10, 36, 5, 29, 9, 21, 11, 21, 26, 34, 16, 22, 14, 24, 27, 13, 18, 24, 27, 35, 30, 5, 17, 10, 25, 25, 20, 35, 4, 23, 35, 24, 33, 16, 12, 35, 15, 5, 7, 14, 32, 33, 18, 25, 21, 6, 34, 35, 8, 5, 24, 17, 26, 25, 4, 32, 25, 24, 22, 10, 31, 5, 15, 29, 19, 27, 26, 25, 12, 9, 10, 11, 18, 
33, 34, 35, 36, 36, 36, 35, 36, 34, 34, 36, 32, 32, 33, 33, 35, 36, 36, 35, 33, 34, 32, 36, 36, 36, 33, 32, 36, 33, 34, 35, 32, 33, 32, 35, 34, 35, 33, 33, 34, 32, 35, 32, 36, 36, 35, 34, 33, 32, 33, 35, 33, 35, 34, 35, 33, 33, 34, 36, 36, 34, 35, 34, 36, 34, 35, 34, 33, 36, 33, 35, 33, 35, 32, 34, 35, 35, 34, 34, 33, 34, 36, 36, 35, 36, 32, 33, 34, 35, 35, 32, 34, 35, 34, 35, 35, 34, 33, 34, 34, 34, 32, 36, 33, 33, 33, 35, 33, 32, 36, 34, 36, 32, 34, 36, 32, 34, 32, 33, 35, 36, 32, 33, 32, 36, 35, 36, 34, 35, 36, 34, 34, 32, 36, 34, 36, 35, 33, 34, 34, 36, 33, 33, 35, 35, 36, 36, 32, 33, 36, 34, 35, 33, 35, 34, 33, 34, 35, 36, 32, 34, 33, 32, 32, 34, 36, 33, 35, 33, 35, 32, 32, 36, 32, 34, 32, 35, 36, 34, 33, 33, 34, 32, 32, 32, 36, 36, 36, 33, 36, 35, 35, 32, 33, 35, 33, 33, 34, 36, 35, 35, 33, 36, 33, 33, 36, 34, 35, 35, 35, 33, 34, 35, 32, 34, 36, 33, 36, 35, 35, 32, 32, 35, 33, 36, 33, 32, 35, 34, 36, 32, 36, 32, 36, 34, 36, 33, 36, 35,  ...
# [[0, 7000], [300, 4377], [600, 1255], [900, 1100], [1200, 1008], [1500, 954], [1800, 930], [2100, 800], [2400, 722], [2700, 643], [3000, 598], [3300, 503], [3600, 411], [3900, 334], [4200, 231], [4500, 169], [4800, 82]]
# [[24], [2], [19], [9], [25], [9], [32], [8], [20], [5], [16], [5], [29], [8], [36], [10], [23], [7], [29], [4], [25], [12], [27], [6], [27], [6], [22], [4], [33], [5], [34], [6], [656], [683], [655], [687], [675]]

# %%
if (L_gare[0][0]<100):
    a='white'
elif (L_gare[0][0]<200):
    a='grey'
elif (L_gare[0][0]<300):
    a='black'
else:
    a='red'

if (L_gare[1][0]<100):
    b='white'
elif (L_gare[1][0]<200):
    b='grey'
elif (L_gare[1][0]<300):
    b='black'
else:
    b='red'

if (L_gare[2][0]<100):
    c='white'
elif (L_gare[2][0]<200):
    c='grey'
elif (L_gare[2][0]<300):
    c='black'
else:
    c='red'

if (L_gare[3][0]<100):
    d='white'
elif (L_gare[3][0]<200):
    d='grey'
elif (L_gare[3][0]<300):
    d='black'
else:
    d='red'

if (L_gare[4][0]<100):
    e='white'
elif (L_gare[4][0]<200):
    e='grey'
elif (L_gare[4][0]<300):
    e='black'
else:
    e='red'

if (L_gare[5][0]<100):
    f='white'
elif (L_gare[5][0]<200):
    f='grey'
elif (L_gare[5][0]<300):
    f='black'
else:
    f='red'

if (L_gare[6][0]<100):
    g='white'
elif (L_gare[6][0]<200):
    g='grey'
elif (L_gare[6][0]<300):
    g='black'
else:
    g='red'

if (L_gare[7][0]<100):
    h='white'
elif (L_gare[7][0]<200):
    h='grey'
elif (L_gare[7][0]<300):
    h='black'
else:
    h='red'

if (L_gare[8][0]<100):
    i='white'
elif (L_gare[8][0]<200):
    i='grey'
elif (L_gare[8][0]<300):
    i='black'
else:
    i='red'

if (L_gare[9][0]<100):
    j='white'
elif (L_gare[9][0]<200):
    j='grey'
elif (L_gare[9][0]<300):
    j='black'
else:
    j='red'

if (L_gare[10][0]<100):
    k='white'
elif (L_gare[10][0]<200):
    k='grey'
elif (L_gare[10][0]<300):
    k='black'
else:
    k='red'

if (L_gare[11][0]<100):
    l='white'
elif (L_gare[11][0]<200):
    l='grey'
elif (L_gare[11][0]<300):
    l='black'
else:
    l='red'

if (L_gare[12][0]<100):
    m='white'
elif (L_gare[12][0]<200):
    m='grey'
elif (L_gare[12][0]<300):
    m='black'
else:
    m='red'

if (L_gare[13][0]<100):
    n='white'
elif (L_gare[13][0]<200):
    n='grey'
elif (L_gare[13][0]<300):
    n='black'
else:
    n='red'

if (L_gare[14][0]<100):
    o='white'
elif (L_gare[14][0]<200):
    o='grey'
elif (L_gare[14][0]<300):
    o='black'
else:
    o='red'

if (L_gare[15][0]<100):
    p='white'
elif (L_gare[15][0]<200):
    p='grey'
elif (L_gare[15][0]<300):
    p='black'
else:
    p='red'

if (L_gare[16][0]<100):
    q='white'
elif (L_gare[16][0]<200):
    q='grey'
elif (L_gare[16][0]<300):
    q='black'
else:
    q='red'

if (L_gare[17][0]<100):
    r='white'
elif (L_gare[17][0]<200):
    r='grey'
elif (L_gare[17][0]<300):
    r='black'
else:
    r='red'

if (L_gare[18][0]<100):
    s='white'
elif (L_gare[18][0]<200):
    s='grey'
elif (L_gare[18][0]<300):
    s='black'
else:
    s='red'

if (L_gare[19][0]<100):
    t='white'
elif (L_gare[19][0]<200):
    t='grey'
elif (L_gare[19][0]<300):
    t='black'
else:
    t='red'

if (L_gare[20][0]<100):
    u='white'
elif (L_gare[20][0]<200):
    u='grey'
elif (L_gare[20][0]<300):
    u='black'
else:
    u='red'

if (L_gare[21][0]<100):
    v='white'
elif (L_gare[21][0]<200):
    v='grey'
elif (L_gare[21][0]<300):
    v='black'
else:
    v='red'

if (L_gare[22][0]<100):
    w='white'
elif (L_gare[22][0]<200):
    w='grey'
elif (L_gare[22][0]<300):
    w='black'
else:
    w='red'

if (L_gare[23][0]<100):
    x='white'
elif (L_gare[23][0]<200):
    x='grey'
elif (L_gare[23][0]<300):
    x='black'
else:
    x='red'

if (L_gare[24][0]<100):
    y='white'
elif (L_gare[24][0]<200):
    y='grey'
elif (L_gare[24][0]<300):
    y='black'
else:
    y='red'

if (L_gare[25][0]<100):
    z='white'
elif (L_gare[25][0]<200):
    z='grey'
elif (L_gare[25][0]<300):
    z='black'
else:
    z='red'

if (L_gare[26][0]<100):
    aa='white'
elif (L_gare[26][0]<200):
    aa='grey'
elif (L_gare[26][0]<300):
    aa='black'
else:
    aa='red'

if (L_gare[27][0]<100):
    bb='white'
elif (L_gare[27][0]<200):
    bb='grey'
elif (L_gare[27][0]<300):
    bb='black'
else:
    bb='red'

if (L_gare[28][0]<100):
    cc='white'
elif (L_gare[28][0]<200):
    cc='grey'
elif (L_gare[28][0]<300):
    cc='black'
else:
    cc='red'

if (L_gare[29][0]<100):
    dd='white'
elif (L_gare[29][0]<200):
    dd='grey'
elif (L_gare[29][0]<300):
    dd='black'
else:
    dd='red'

if (L_gare[30][0]<100):
    ee='white'
elif (L_gare[30][0]<200):
    ee='grey'
elif (L_gare[30][0]<300):
    ee='black'
else:
    ee='red'

if (L_gare[31][0]<100):
    ff='white'
elif (L_gare[31][0]<200):
    ff='grey'
elif (L_gare[31][0]<300):
    ff='black'
else:
    ff='red'

if (L_gare[32][0]<100):
    gg='white'
elif (L_gare[32][0]<200):
    gg='grey'
elif (L_gare[32][0]<300):
    gg='black'
else:
    gg='red'

if (L_gare[33][0]<100):
    hh='white'
elif (L_gare[33][0]<200):
    hh='grey'
elif (L_gare[33][0]<300):
    hh='black'
else:
    hh='red'

if (L_gare[34][0]<100):
    ii='white'
elif (L_gare[34][0]<200):
    ii='grey'
elif (L_gare[34][0]<300):
    ii='black'
else:
    ii='red'

if (L_gare[35][0]<100):
    jj='white'
elif (L_gare[35][0]<200):
    jj='grey'
elif (L_gare[35][0]<300):
    jj='black'
else:
    jj='red'

if (L_gare[36][0]<100):
    kk='white'
elif (L_gare[36][0]<200):
    kk='grey'
elif (L_gare[36][0]<300):
    kk='black'
else:
    kk='red'

# %%
from tkinter import * 


fenetre = Tk()

photo = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")

canvas = Canvas(fenetre,width=1440, height=480)
canvas.create_image(0, 0, anchor=NW, image=photo)

canvas.create_oval(231,256,247,272,fill=a)
canvas.create_oval(255,256,270,272,fill=b)
canvas.create_oval(285,256,300,272,fill=c)
canvas.create_oval(315,256,330,272,fill=d)
canvas.create_oval(350,256,365,272,fill=e)
canvas.create_oval(382,256,397,272,fill=f)
canvas.create_oval(412,256,427,272,fill=g)
canvas.create_oval(440,256,455,272,fill=h)
canvas.create_oval(470,256,485,272,fill=i)

canvas.create_oval(502,256,517,272,fill=j)
canvas.create_oval(530,256,545,272,fill=k)
canvas.create_oval(555,256,570,272,fill=l)
canvas.create_oval(582,256,597,272,fill=m)
canvas.create_oval(610,256,625,272,fill=n)
canvas.create_oval(638,256,653,272,fill=o)
canvas.create_oval(665,256,680,272,fill=p)
canvas.create_oval(692,256,707,272,fill=q)
canvas.create_oval(720,256,735,272,fill=r)

canvas.create_oval(747,256,762,272,fill=s)
canvas.create_oval(775,256,790,272,fill=t)
canvas.create_oval(807,256,822,272,fill=u)
canvas.create_oval(839,256,854,272,fill=v)
canvas.create_oval(880,256,895,272,fill=w)
canvas.create_oval(910,256,925,272,fill=x)
canvas.create_oval(940,256,955,272,fill=y)
canvas.create_oval(972,256,987,272,fill=z)
canvas.create_oval(1000,256,1015,272,fill=aa)

canvas.create_oval(1030,256,1045,272,fill=bb)
canvas.create_oval(1060,256,1075,272,fill=cc)
canvas.create_oval(1093,256,1108,272,fill=dd)
canvas.create_oval(1123,256,1138,272,fill=ee)
canvas.create_oval(1155,256,1170,272,fill=ff)
canvas.create_oval(1185,256,1200,272,fill=gg)
canvas.create_oval(1214,256,1229,272,fill=hh)
canvas.create_oval(1245,256,1260,272,fill=ii)
canvas.create_oval(1280,256,1295,272,fill=jj)

canvas.create_oval(1310,256,1325,272,fill=kk)

canvas.pack()
fenetre.mainloop()

# %% [markdown]
# ###

# %%
for i in range(0):
    print(i)

# %%
L=[1]
del L[0]
print(len(L))
# Out:
# 0
