# %%
# %matplotlib inline

from pylab import *

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
#from LibMetroIti_NB import *

# %%
nombredestation=37


L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
L_changement_train=[] #Liste de liste similaire L_dest_train sauf qu'au lieu de la destination sur la ligne on a la dest final
L_changement_gare=[] #Liste de liste similaire L_dest_gare sauf qu'au lieu de la destination sur la ligne on a la dest final
for i in range(nombredestation):
    L_changement_gare.append([])
    
    
def simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,ta,cm, bio, tbio):
    L_del = []
    if (t%(24*3600)>3600 and t%(24*3600)<3600*6):
        bio2=100000
        bio3=0
    elif ((t%(24*3600)>3600*7 and t%(24*3600)<3600*9) or (t%(24*3600)>3600*16 and t%(24*3600)<3600*20)):
        bio2 = 200
        bio3= 8
    else :
        bio2 = 300
        bio3 = 3
    for i in range(bio3):
        a=np.random.choice(len(L_gare) - 1)
        L_gare[a][0]+=1
        L_dest_gare[a].append(np.random.choice(len(L_gare) - a - 1)+ a + 1)
        """
        dest=np.random.choice(len(L_gare)-a)+a
        if (sur la meme ligne):
            L_changement_gare[a].append(-1)
            L_dest_gare[a].append(dest)
        else:
            L_dest_gare[a].append(premier_changement)
            L_changement_gare[a].append(dest)

        """
    if (t - bio < 0 or t - bio > tbio):
        if(y%bio2==0):
            L_train.append([t,0])
            L_dest_train.append([])

        for i in range(len(L_train)):
            if((t-L_train[i][0])%ta==0): # test pour savoir si un metro est arrive a une station
                if ((t-L_train[i][0])//ta<nombredestation):
                    x=(t-L_train[i][0])//ta   # x correspond a l'indice de la station ou un train se situe
                    c = -1
                    for k in range(len(L_train)): 
                        if (L_train[k][0] == t - ta * x): # test pour savoir si il s'agit du train qui est a quai
                            c = k # c correspond a l'indice du train qui est a quai
                            ns=len(L_dest_train[c])
                            m=0
                            while(m<ns): #les passagers arrivé a destination sortent du train
                                if(L_dest_train[c][m]==x):
                                    del L_dest_train[c][m]
                                    L_train[c][1]-=1 
                                    ns-=1
                                m+=1
                            if (L_train[c][0] == t - ta * (nombredestation - 1)):#test si on est en terminus (tous le monde descend)

                                L_train[c][1] = 0
                                L_dest_train[c] = []
                                L_del.append(c)
                            if(L_gare[x][0]<cm-L_train[i][1]): # les passagers rentrent dans le train quand celui ci est a quai
                                L_train[i][1]=L_train[i][1]+L_gare[x][0]
                                for j in range(len(L_dest_gare[x])):
                                    L_dest_train[c].append(L_dest_gare[x][j])
                                L_dest_gare[x]=[]
                                L_gare[x][0]=0
                            else:
                                L_gare[x][0]=L_gare[x][0]-(cm-L_train[i][1])
                                for j in range(cm-L_train[i][1]):
                                    L_dest_train[c].append(L_dest_gare[x][0])
                                    del L_dest_gare[x][0]
                                L_train[i][1]=cm
        for i in range(len(L_del)):
            del L_dest_train[L_del[-i]]
            del L_train[L_del[-i]]

# %%
""" test a faire : dans une journée on recupere les infos tout les quart d'heure (simu map) et on bloquera le reseau pendant 
3h afin de voir l'accumulation des passagers"""
# Out:
# " test a faire : dans une journée on recupere les infos tout les quart d'heure (simu map) et on bloquera le reseau pendant \n3h afin de voir l'accumulation des passagers"

# %% [markdown]
# ###

# %%
from tkinter import * 
import time

L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])

L_couleur=[]
for i in range(nombredestation):
    L_couleur.append([])

nbstep = 24*3600
y=0
t=0
fenetre = Tk()
photo = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")
canvas = Canvas(fenetre,width=1441, height=481)
canvas.create_image(0, 0, anchor=NW, image=photo)
station1=canvas.create_oval(231,256,247,272,fill='white')
station2 = canvas.create_oval(255,256,270,272,fill='white')
station3 = canvas.create_oval(285,256,300,272,fill='white')
station4 = canvas.create_oval(315,256,330,272,fill='white')
station5=canvas.create_oval(350,256,365,272,fill='white')
station6=canvas.create_oval(382,256,397,272,fill='white')
station7=canvas.create_oval(412,256,427,272,fill='white')
station8=canvas.create_oval(440,256,455,272,fill='white')
station9=canvas.create_oval(470,256,485,272,fill='white')
station10=canvas.create_oval(502,256,517,272,fill='white')
station11=canvas.create_oval(530,256,545,272,fill='white')
station12=canvas.create_oval(555,256,570,272,fill='white')
station13=canvas.create_oval(582,256,597,272,fill='white')
station14=canvas.create_oval(610,256,625,272,fill='white')
station15=canvas.create_oval(638,256,653,272,fill='white')
station16=canvas.create_oval(665,256,680,272,fill='white')
station17=canvas.create_oval(692,256,707,272,fill='white')
station18=canvas.create_oval(720,256,735,272,fill='white')
station19=canvas.create_oval(747,256,762,272,fill='white')
station20=canvas.create_oval(775,256,790,272,fill='white')
station21=canvas.create_oval(807,256,822,272,fill='white')
station22=canvas.create_oval(839,256,854,272,fill='white')
station23=canvas.create_oval(880,256,895,272,fill='white')
station24=canvas.create_oval(910,256,925,272,fill='white')
station25=canvas.create_oval(940,256,955,272,fill='white')
station26=canvas.create_oval(972,256,987,272,fill='white')
station27=canvas.create_oval(1000,256,1015,272,fill='white')
station28=canvas.create_oval(1030,256,1045,272,fill='white')
station29=canvas.create_oval(1060,256,1075,272,fill='white')
station30=canvas.create_oval(1093,256,1108,272,fill='white')
station31=canvas.create_oval(1123,256,1138,272,fill='white')
station32=canvas.create_oval(1155,256,1170,272,fill='white')
station33=canvas.create_oval(1185,256,1200,272,fill='white')
station34=canvas.create_oval(1214,256,1229,272,fill='white')
station35=canvas.create_oval(1245,256,1260,272,fill='white')
station36=canvas.create_oval(1280,256,1295,272,fill='white')
station37=canvas.create_oval(1310,256,1325,272,fill='white')

# legende
canvas.create_rectangle(231,350,301,380,fill='#1E90FF')
canvas.create_text(256,390,text="de 0 à 10")
canvas.create_rectangle(301,350,371,380,fill='cyan')
canvas.create_text(306,390,text="de 10 à 20")
canvas.create_rectangle(371,350,441,380,fill='#00FF00')
canvas.create_text(356,390,text="de 20 à 30")
canvas.create_rectangle(511,350,431,380,fill='yellow')
canvas.create_text(406,390,text="de 30 à 40")
canvas.create_rectangle(431,350,481,380,fill='#FFA500')
canvas.create_text(456,390,text="de 40 à  50")
canvas.create_rectangle(481,350,531,380,fill='red')
canvas.create_text(506,390,text="+ de 50")


canvas.create_rectangle(580,420,660,440,fill='white',outline="")# gommage d'une erreur de rognage (ne pas effacer)
accident = 90000
tacc = 0

for i in range(nbstep):
    simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,150,700, accident, tacc)
    y+=1
    t+=1
    if (i%(10)==0):
        for j in range(nombredestation):
            if (L_gare[j][0]<10):
                L_couleur[j]='#1E90FF'
            elif (L_gare[j][0]<20):
                L_couleur[j]='cyan'
            elif (L_gare[j][0]<30):
                L_couleur[j]='#00FF00'
            elif (L_gare[j][0]<40):
                L_couleur[j]='yellow'
            elif (L_gare[j][0]<50):
                L_couleur[j]='#FFA500'
            else:
                L_couleur[j]='red'
        
        canvas.delete(station1)
        station1=canvas.create_oval(231,256,247,272,fill=L_couleur[0])
        canvas.delete(station2)
        station2 = canvas.create_oval(255,256,270,272,fill=L_couleur[1])
        canvas.delete(station3)
        station3 = canvas.create_oval(285,256,300,272,fill=L_couleur[2])
        canvas.delete(station4)
        station4 = canvas.create_oval(315,256,330,272,fill=L_couleur[3])
        canvas.delete(station5)
        station5=canvas.create_oval(350,256,365,272,fill=L_couleur[4])
        canvas.delete(station6)
        station6=canvas.create_oval(382,256,397,272,fill=L_couleur[5])
        canvas.delete(station7)
        station7=canvas.create_oval(412,256,427,272,fill=L_couleur[6])
        canvas.delete(station8)
        station8=canvas.create_oval(440,256,455,272,fill=L_couleur[7])
        canvas.delete(station9)
        station9=canvas.create_oval(470,256,485,272,fill=L_couleur[8])
        canvas.delete(station10)
        station10=canvas.create_oval(502,256,517,272,fill=L_couleur[9])
        canvas.delete(station11)
        station11=canvas.create_oval(530,256,545,272,fill=L_couleur[10])
        canvas.delete(station12)
        station12=canvas.create_oval(555,256,570,272,fill=L_couleur[11])
        canvas.delete(station13)
        station13=canvas.create_oval(582,256,597,272,fill=L_couleur[12])
        canvas.delete(station14)
        station14=canvas.create_oval(610,256,625,272,fill=L_couleur[13])
        canvas.delete(station15)
        station15=canvas.create_oval(638,256,653,272,fill=L_couleur[14])
        canvas.delete(station16)
        station16=canvas.create_oval(665,256,680,272,fill=L_couleur[15])
        canvas.delete(station17)
        station17=canvas.create_oval(692,256,707,272,fill=L_couleur[16])
        canvas.delete(station18)
        station18=canvas.create_oval(720,256,735,272,fill=L_couleur[17])
        canvas.delete(station19)
        station19=canvas.create_oval(747,256,762,272,fill=L_couleur[18])
        canvas.delete(station20)
        station20=canvas.create_oval(775,256,790,272,fill=L_couleur[19])
        canvas.delete(station21)
        station21=canvas.create_oval(807,256,822,272,fill=L_couleur[20])
        canvas.delete(station22)
        station22=canvas.create_oval(839,256,854,272,fill=L_couleur[21])
        canvas.delete(station23)
        station23=canvas.create_oval(880,256,895,272,fill=L_couleur[22])
        canvas.delete(station24)
        station24=canvas.create_oval(910,256,925,272,fill=L_couleur[23])
        canvas.delete(station25)
        station25=canvas.create_oval(940,256,955,272,fill=L_couleur[24])
        canvas.delete(station26)
        station26=canvas.create_oval(972,256,987,272,fill=L_couleur[25])
        canvas.delete(station27)
        station27=canvas.create_oval(1000,256,1015,272,fill=L_couleur[26])
        canvas.delete(station28)
        station28=canvas.create_oval(1030,256,1045,272,fill=L_couleur[27])
        canvas.delete(station29)
        station29=canvas.create_oval(1060,256,1075,272,fill=L_couleur[28])
        canvas.delete(station30)
        station30=canvas.create_oval(1093,256,1108,272,fill=L_couleur[29])
        canvas.delete(station31)
        station31=canvas.create_oval(1123,256,1138,272,fill=L_couleur[30])
        canvas.delete(station32)
        station32=canvas.create_oval(1155,256,1170,272,fill=L_couleur[31])
        canvas.delete(station33)
        station33=canvas.create_oval(1185,256,1200,272,fill=L_couleur[32])
        canvas.delete(station34)
        station34=canvas.create_oval(1214,256,1229,272,fill=L_couleur[33])
        canvas.delete(station35)
        station35=canvas.create_oval(1245,256,1260,272,fill=L_couleur[34])
        canvas.delete(station36)
        station36=canvas.create_oval(1280,256,1295,272,fill=L_couleur[35])
        canvas.delete(station37)
        station37=canvas.create_oval(1310,256,1325,272,fill=L_couleur[36])

        
        canvas.pack()
        time.sleep(0.001)
        canvas.update()
fenetre.mainloop()

print(L_train)
print("1111111111111111111111111111111111111111111111111111111111111111111111111")
print(L_gare)
print("2222222222222222222222222222222222222222222222222222222222222222222222222")
print(L_dest_train)
print("3333333333333333333333333333333333333333333333333333333333333333333333333")
print(L_dest_gare)
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-15-443c868d6f2e> in <module>()
#      99                 L_couleur[j]='red'
#     100
# --> 101         canvas.delete(station1)
#     102         station1=canvas.create_oval(231,256,247,272,fill=L_couleur[0])
#     103         canvas.delete(station2)
#
# ~\Anaconda3\lib\tkinter\__init__.py in delete(self, *args)
#    2506     def delete(self, *args):
#    2507         """Delete items identified by all tag or ids contained in ARGS."""
# -> 2508         self.tk.call((self._w, 'delete') + args)
#    2509     def dtag(self, *args):
#    2510         """Delete tag or id given as last arguments in ARGS from items
#
# TclError: invalid command name ".!canvas"

# %%
"""

canvas.delete(station1)
        canvas.create_oval(255,256,270,272,fill=L_couleur[1])
        canvas.create_oval(285,256,300,272,fill=L_couleur[2])
        canvas.create_oval(315,256,330,272,fill=L_couleur[3])
        canvas.create_oval(350,256,365,272,fill=L_couleur[4])
        canvas.create_oval(382,256,397,272,fill=L_couleur[5])
        canvas.create_oval(412,256,427,272,fill=L_couleur[6])
        canvas.create_oval(440,256,455,272,fill=L_couleur[7])
        canvas.create_oval(470,256,485,272,fill=L_couleur[8])
        canvas.create_oval(502,256,517,272,fill=L_couleur[9])
        canvas.create_oval(530,256,545,272,fill=L_couleur[10])
        canvas.create_oval(555,256,570,272,fill=L_couleur[11])
        canvas.create_oval(582,256,597,272,fill=L_couleur[12])
        canvas.create_oval(610,256,625,272,fill=L_couleur[13])
        canvas.create_oval(638,256,653,272,fill=L_couleur[14])
        canvas.create_oval(665,256,680,272,fill=L_couleur[15])
        canvas.create_oval(692,256,707,272,fill=L_couleur[16])
        canvas.create_oval(720,256,735,272,fill=L_couleur[17])
        canvas.create_oval(747,256,762,272,fill=L_couleur[18])
        canvas.create_oval(775,256,790,272,fill=L_couleur[19])
        canvas.create_oval(807,256,822,272,fill=L_couleur[20])
        canvas.create_oval(839,256,854,272,fill=L_couleur[21])
        canvas.create_oval(880,256,895,272,fill=L_couleur[22])
        canvas.create_oval(910,256,925,272,fill=L_couleur[23])
        canvas.create_oval(940,256,955,272,fill=L_couleur[24])
        canvas.create_oval(972,256,987,272,fill=L_couleur[25])
        canvas.create_oval(1000,256,1015,272,fill=L_couleur[26])
        canvas.create_oval(1030,256,1045,272,fill=L_couleur[27])
        canvas.create_oval(1060,256,1075,272,fill=L_couleur[28])
        canvas.create_oval(1093,256,1108,272,fill=L_couleur[29])
        canvas.create_oval(1123,256,1138,272,fill=L_couleur[30])
        canvas.create_oval(1155,256,1170,272,fill=L_couleur[31])
        canvas.create_oval(1185,256,1200,272,fill=L_couleur[32])
        canvas.create_oval(1214,256,1229,272,fill=L_couleur[33])
        canvas.create_oval(1245,256,1260,272,fill=L_couleur[34])
        canvas.create_oval(1280,256,1295,272,fill=L_couleur[35])
        canvas.create_oval(1310,256,1325,272,fill=L_couleur[36])



from tkinter import * 
import time


nbstep = 24*3600
yes=0
bon=0

a='white'
b='white'
c='white'
d='white'
e='white'
f='white'
g='white'
h='white'
i='white'
j='white'
k='white'
l='white'
m='white'
n='white'
o='white'
p='white'
q='white'
r='white'
s='white'
t='white'
u='white'
v='white'
w='white'
x='white'
y='white'
z='white'
aa='white'
bb='white'
cc='white'
dd='white'
ee='white'
ff='white'
gg='white'
hh='white'
ii='white'
jj='white'
kk='white'
fenetre = Tk()

photo = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")

canvas = Canvas(fenetre,width=1440, height=480)
canvas.create_image(0, 0, anchor=NW, image=photo)

canvas.create_oval(231,256,247,272,fill=a)
canvas.create_oval(255,256,270,272,fill=b)
canvas.create_oval(285,256,300,272,fill=c)
canvas.create_oval(315,256,330,272,fill=d)
canvas.create_oval(350,256,365,272,fill=e)
canvas.create_oval(382,256,397,272,fill=f)
canvas.create_oval(412,256,427,272,fill=g)
canvas.create_oval(440,256,455,272,fill=h)
canvas.create_oval(470,256,485,272,fill=i)

canvas.create_oval(502,256,517,272,fill=j)
canvas.create_oval(530,256,545,272,fill=k)
canvas.create_oval(555,256,570,272,fill=l)
canvas.create_oval(582,256,597,272,fill=m)
canvas.create_oval(610,256,625,272,fill=n)
canvas.create_oval(638,256,653,272,fill=o)
canvas.create_oval(665,256,680,272,fill=p)
canvas.create_oval(692,256,707,272,fill=q)
canvas.create_oval(720,256,735,272,fill=r)

canvas.create_oval(747,256,762,272,fill=s)
canvas.create_oval(775,256,790,272,fill=t)
canvas.create_oval(807,256,822,272,fill=u)
canvas.create_oval(839,256,854,272,fill=v)
canvas.create_oval(880,256,895,272,fill=w)
canvas.create_oval(910,256,925,272,fill=x)
canvas.create_oval(940,256,955,272,fill=y)
canvas.create_oval(972,256,987,272,fill=z)
canvas.create_oval(1000,256,1015,272,fill=aa)

canvas.create_oval(1030,256,1045,272,fill=bb)
canvas.create_oval(1060,256,1075,272,fill=cc)
canvas.create_oval(1093,256,1108,272,fill=dd)
canvas.create_oval(1123,256,1138,272,fill=ee)
canvas.create_oval(1155,256,1170,272,fill=ff)
canvas.create_oval(1185,256,1200,272,fill=gg)
canvas.create_oval(1214,256,1229,272,fill=hh)
canvas.create_oval(1245,256,1260,272,fill=ii)
canvas.create_oval(1280,256,1295,272,fill=jj)

canvas.create_oval(1310,256,1325,272,fill=kk)

canvas.pack()
for ok in range(nbstep):
    simulation(L_gare,L_train,L_dest_gare,L_dest_train,bon,yes,150,7000)
    yes+=1
    bon+=1

    
    if (ok%3600==0):
        if (L_gare[0][0]<100):
            a='white'
        elif (L_gare[0][0]<200):
            a='grey'
        elif (L_gare[0][0]<300):
            a='black'
        else:
            a='red'

        if (L_gare[1][0]<100):
            b='white'
        elif (L_gare[1][0]<200):
            b='grey'
        elif (L_gare[1][0]<300):
            b='black'
        else:
            b='red'

        if (L_gare[2][0]<100):
            c='white'
        elif (L_gare[2][0]<200):
            c='grey'
        elif (L_gare[2][0]<300):
            c='black'
        else:
            c='red'

        if (L_gare[3][0]<100):
            d='white'
        elif (L_gare[3][0]<200):
            d='grey'
        elif (L_gare[3][0]<300):
            d='black'
        else:
            d='red'

        if (L_gare[4][0]<100):
            e='white'
        elif (L_gare[4][0]<200):
            e='grey'
        elif (L_gare[4][0]<300):
            e='black'
        else:
            e='red'

        if (L_gare[5][0]<100):
            f='white'
        elif (L_gare[5][0]<200):
            f='grey'
        elif (L_gare[5][0]<300):
            f='black'
        else:
            f='red'

        if (L_gare[6][0]<100):
            g='white'
        elif (L_gare[6][0]<200):
            g='grey'
        elif (L_gare[6][0]<300):
            g='black'
        else:
            g='red'

        if (L_gare[7][0]<100):
            h='white'
        elif (L_gare[7][0]<200):
            h='grey'
        elif (L_gare[7][0]<300):
            h='black'
        else:
            h='red'

        if (L_gare[8][0]<100):
            i='white'
        elif (L_gare[8][0]<200):
            i='grey'
        elif (L_gare[8][0]<300):
            i='black'
        else:
            i='red'

        if (L_gare[9][0]<100):
            j='white'
        elif (L_gare[9][0]<200):
            j='grey'
        elif (L_gare[9][0]<300):
            j='black'
        else:
            j='red'

        if (L_gare[10][0]<100):
            k='white'
        elif (L_gare[10][0]<200):
            k='grey'
        elif (L_gare[10][0]<300):
            k='black'
        else:
            k='red'

        if (L_gare[11][0]<100):
            l='white'
        elif (L_gare[11][0]<200):
            l='grey'
        elif (L_gare[11][0]<300):
            l='black'
        else:
            l='red'

        if (L_gare[12][0]<100):
            m='white'
        elif (L_gare[12][0]<200):
            m='grey'
        elif (L_gare[12][0]<300):
            m='black'
        else:
            m='red'

        if (L_gare[13][0]<100):
            n='white'
        elif (L_gare[13][0]<200):
            n='grey'
        elif (L_gare[13][0]<300):
            n='black'
        else:
            n='red'

        if (L_gare[14][0]<100):
            o='white'
        elif (L_gare[14][0]<200):
            o='grey'
        elif (L_gare[14][0]<300):
            o='black'
        else:
            o='red'

        if (L_gare[15][0]<100):
            p='white'
        elif (L_gare[15][0]<200):
            p='grey'
        elif (L_gare[15][0]<300):
            p='black'
        else:
            p='red'

        if (L_gare[16][0]<100):
            q='white'
        elif (L_gare[16][0]<200):
            q='grey'
        elif (L_gare[16][0]<300):
            q='black'
        else:
            q='red'

        if (L_gare[17][0]<100):
            r='white'
        elif (L_gare[17][0]<200):
            r='grey'
        elif (L_gare[17][0]<300):
            r='black'
        else:
            r='red'

        if (L_gare[18][0]<100):
            s='white'
        elif (L_gare[18][0]<200):
            s='grey'
        elif (L_gare[18][0]<300):
            s='black'
        else:
            s='red'

        if (L_gare[19][0]<100):
            t='white'
        elif (L_gare[19][0]<200):
            t='grey'
        elif (L_gare[19][0]<300):
            t='black'
        else:
            t='red'

        if (L_gare[20][0]<100):
            u='white'
        elif (L_gare[20][0]<200):
            u='grey'
        elif (L_gare[20][0]<300):
            u='black'
        else:
            u='red'

        if (L_gare[21][0]<100):
            v='white'
        elif (L_gare[21][0]<200):
            v='grey'
        elif (L_gare[21][0]<300):
            v='black'
        else:
            v='red'

        if (L_gare[22][0]<100):
            w='white'
        elif (L_gare[22][0]<200):
            w='grey'
        elif (L_gare[22][0]<300):
            w='black'
        else:
            w='red'

        if (L_gare[23][0]<100):
            x='white'
        elif (L_gare[23][0]<200):
            x='grey'
        elif (L_gare[23][0]<300):
            x='black'
        else:
            x='red'

        if (L_gare[24][0]<100):
            y='white'
        elif (L_gare[24][0]<200):
            y='grey'
        elif (L_gare[24][0]<300):
            y='black'
        else:
            y='red'

        if (L_gare[25][0]<100):
            z='white'
        elif (L_gare[25][0]<200):
            z='grey'
        elif (L_gare[25][0]<300):
            z='black'
        else:
            z='red'

        if (L_gare[26][0]<100):
            aa='white'
        elif (L_gare[26][0]<200):
            aa='grey'
        elif (L_gare[26][0]<300):
            aa='black'
        else:
            aa='red'

        if (L_gare[27][0]<100):
            bb='white'
        elif (L_gare[27][0]<200):
            bb='grey'
        elif (L_gare[27][0]<300):
            bb='black'
        else:
            bb='red'

        if (L_gare[28][0]<100):
            cc='white'
        elif (L_gare[28][0]<200):
            cc='grey'
        elif (L_gare[28][0]<300):
            cc='black'
        else:
            cc='red'

        if (L_gare[29][0]<100):
            dd='white'
        elif (L_gare[29][0]<200):
            dd='grey'
        elif (L_gare[29][0]<300):
            dd='black'
        else:
            dd='red'

        if (L_gare[30][0]<100):
            ee='white'
        elif (L_gare[30][0]<200):
            ee='grey'
        elif (L_gare[30][0]<300):
            ee='black'
        else:
            ee='red'

        if (L_gare[31][0]<100):
            ff='white'
        elif (L_gare[31][0]<200):
            ff='grey'
        elif (L_gare[31][0]<300):
            ff='black'
        else:
            ff='red'

        if (L_gare[32][0]<100):
            gg='white'
        elif (L_gare[32][0]<200):
            gg='grey'
        elif (L_gare[32][0]<300):
            gg='black'
        else:
            gg='red'

        if (L_gare[33][0]<100):
            hh='white'
        elif (L_gare[33][0]<200):
            hh='grey'
        elif (L_gare[33][0]<300):
            hh='black'
        else:
            hh='red'

        if (L_gare[34][0]<100):
            ii='white'
        elif (L_gare[34][0]<200):
            ii='grey'
        elif (L_gare[34][0]<300):
            ii='black'
        else:
            ii='red'

        if (L_gare[35][0]<100):
            jj='white'
        elif (L_gare[35][0]<200):
            jj='grey'
        elif (L_gare[35][0]<300):
            jj='black'
        else:
            jj='red'

        if (L_gare[36][0]<100):
            kk='white'
        elif (L_gare[36][0]<200):
            kk='grey'
        elif (L_gare[36][0]<300):
            kk='black'
        else:
            kk='red'
        canvas.move()
        time.sleep(2)
        canvas.update()
    fenetre.mainloop()"""
