# %%
# %matplotlib inline

from pylab import *

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os
import numpy as np
#from LibMetroIti_NB import *

# %%
nombredestation=37


L_train=[]# [[temps ou le train apparait , le nombre de personne dans le train]]
L_gare=[]# liste du nombre de personne dans toutes les gares
for i in range(nombredestation):
    L_gare.append([0])
L_dest_train=[] # liste de liste de la destination de chaque personne dans un train
L_dest_gare=[] # liste de liste de la destination de chaque personne dans une station
for i in range(nombredestation):
    L_dest_gare.append([])
L_changement_train=[] #Liste de liste similaire L_dest_train sauf qu'au lieu de la destination sur la ligne on a la dest final
L_changement_gare=[] #Liste de liste similaire L_dest_gare sauf qu'au lieu de la destination sur la ligne on a la dest final
for i in range(nombredestation):
    L_changement_gare.append([])
    
    
def simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,ta,cm):
    bio=t
    for i in range(5):
        a=np.random.choice(len(L_gare))
        L_gare[a][0]+=1
        L_dest_gare[a].append(np.random.choice(len(L_gare)-a)+a)
        """
        dest=np.random.choice(len(L_gare)-a)+a
        if (sur la meme ligne):
            L_changement_gare[a].append(-1)
            L_dest_gare[a].append(dest)
        else:
            L_dest_gare[a].append(premier_changement)
            L_changement_gare[a].append(dest)

        """
    if(y%300==0):
        L_train.append([bio,0])
        L_dest_train.append([])
    
    for i in range(len(L_train)):
        if((t-L_train[i][0])%ta==0): # test pour savoir si un metro est arrive a une station
            if ((t-L_train[i][0])//ta<nombredestation):
                x=(t-L_train[i][0])//ta   # x correspond a l'indice de la station ou un train se situe
                c = -1
                for k in range(len(L_train)): 
                    if (L_train[k][0] == t - ta * x): # test pour savoir si il s'agit du train qui est a quai
                        c = k # c correspond a l'indice du train qui est a quai
                if (c!=-1): # test totalement inutile car on sait deja qu'un train est a quai
                    ns=len(L_dest_train[c])
                    m=0
                    while(m<ns): #les passagers arrivé a destination sortent du train
                        if(L_dest_train[c][m]==x):
                            del L_dest_train[c][m]
                            L_train[c][1]-=1 
                            ns-=1
                        m+=1
                    if(L_gare[x][0]<cm-L_train[i][1]): # les passagers rentrent dans le train quand celui ci est a quai
                        L_train[i][1]=L_train[i][1]+L_gare[x][0]
                        for j in range(len(L_dest_gare[x])):
                            L_dest_train[c].append(L_dest_gare[x][j])
                        L_dest_gare[x]=[]
                        L_gare[x][0]=0
                    else:
                        L_gare[x][0]=L_gare[x][0]-(cm-L_train[i][1])
                        for j in range(cm-L_train[i][1]):
                            L_dest_train[c].append(L_dest_gare[x][0])
                            del L_dest_gare[x][0]
                        L_train[i][1]=cm

# %%
""" test a faire : dans une journée on recupere les infos tout les quart d'heure (simu map) et on bloquera le reseau pendant 
3h afin de voir l'accumulation des passagers"""
# Out:
# " test a faire : dans une journée on recupere les infos tout les quart d'heure (simu map) et on bloquera le reseau pendant \n3h afin de voir l'accumulation des passagers"

# %% [markdown]
# ###

# %%
from tkinter import * 

L_couleur=[]
for i in range(nombredestation):
    L_couleur.append([])

nbstep = 24*3600
y=0
t=0
for i in range(nbstep):
    simulation(L_gare,L_train,L_dest_gare,L_dest_train,t,y,150,7000)
    y+=1
    t+=1
    if (i%(24*3600)==0):
        for j in range(nombredestation):
            if (L_gare[j][0]<100):
                L_couleur[j]='white'
            elif (L_gare[j][0]<200):
                L_couleur[j]='grey'
            elif (L_gare[j][0]<300):
                L_couleur[j]='black'
            else:
                L_couleur[j]='red'
        fenetre = Tk()
        photo = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")
        canvas = Canvas(fenetre,width=1440, height=480)
        canvas.create_image(0, 0, anchor=NW, image=photo)
        canvas.create_oval(231,256,247,272,fill=L_couleur[0])
        canvas.create_oval(255,256,270,272,fill=L_couleur[1])
        canvas.create_oval(285,256,300,272,fill=L_couleur[2])
        canvas.create_oval(315,256,330,272,fill=L_couleur[3])
        canvas.create_oval(350,256,365,272,fill=L_couleur[4])
        canvas.create_oval(382,256,397,272,fill=L_couleur[5])
        canvas.create_oval(412,256,427,272,fill=L_couleur[6])
        canvas.create_oval(440,256,455,272,fill=L_couleur[7])
        canvas.create_oval(470,256,485,272,fill=L_couleur[8])
        canvas.create_oval(502,256,517,272,fill=L_couleur[9])
        canvas.create_oval(530,256,545,272,fill=L_couleur[10])
        canvas.create_oval(555,256,570,272,fill=L_couleur[11])
        canvas.create_oval(582,256,597,272,fill=L_couleur[12])
        canvas.create_oval(610,256,625,272,fill=L_couleur[13])
        canvas.create_oval(638,256,653,272,fill=L_couleur[14])
        canvas.create_oval(665,256,680,272,fill=L_couleur[15])
        canvas.create_oval(692,256,707,272,fill=L_couleur[16])
        canvas.create_oval(720,256,735,272,fill=L_couleur[17])
        canvas.create_oval(747,256,762,272,fill=L_couleur[18])
        canvas.create_oval(775,256,790,272,fill=L_couleur[19])
        canvas.create_oval(807,256,822,272,fill=L_couleur[20])
        canvas.create_oval(839,256,854,272,fill=L_couleur[21])
        canvas.create_oval(880,256,895,272,fill=L_couleur[22])
        canvas.create_oval(910,256,925,272,fill=L_couleur[23])
        canvas.create_oval(940,256,955,272,fill=L_couleur[24])
        canvas.create_oval(972,256,987,272,fill=L_couleur[25])
        canvas.create_oval(1000,256,1015,272,fill=L_couleur[26])
        canvas.create_oval(1030,256,1045,272,fill=L_couleur[27])
        canvas.create_oval(1060,256,1075,272,fill=L_couleur[28])
        canvas.create_oval(1093,256,1108,272,fill=L_couleur[29])
        canvas.create_oval(1123,256,1138,272,fill=L_couleur[30])
        canvas.create_oval(1155,256,1170,272,fill=L_couleur[31])
        canvas.create_oval(1185,256,1200,272,fill=L_couleur[32])
        canvas.create_oval(1214,256,1229,272,fill=L_couleur[33])
        canvas.create_oval(1245,256,1260,272,fill=L_couleur[34])
        canvas.create_oval(1280,256,1295,272,fill=L_couleur[35])
        canvas.create_oval(1310,256,1325,272,fill=L_couleur[36])
        canvas.pack()
        fenetre.mainloop()
        
        
        
        
print(L_dest_train)
 345], [56100, 335], [56400, 314], [56700, 354], [57000, 286], [57300, 353], [57600, 299], [57900, 318], [58200, 310], [58500, 327], [58800, 334], [59100, 316], [59400, 322], [59700, 322], [60000, 342], [60300, 301], [60600, 336], [60900, 332], [61200, 338], [61500, 325], [61800, 313], [62100, 334], [62400, 303], [62700, 326], [63000, 323], [63300, 309], [63600, 324], [63900, 339], [64200, 342], [64500, 343], [64800, 312], [65100, 328], [65400, 321], [65700, 334], [66000, 326], [66300, 327], [66600, 313], [66900, 324], [67200, 319], [67500, 340], [67800, 322], [68100, 328], [68400, 316], [68700, 335], [69000, 300], [69300, 284], [69600, 332], [69900, 310], [70200, 324], [70500, 349], [70800, 301], [71100, 287], [71400, 324], [71700, 321], [72000, 332], [72300, 317], [72600, 318], [72900, 333], [73200, 330], [73500, 325], [73800, 300], [74100, 320], [74400, 364], [74700, 328], [75000, 309], [75300, 297], [75600, 307], [75900, 322], [76200, 302], [76500, 331], [76800, 311], [77100, 350], [77400, 312], [77700, 324], [78000, 332], [78300, 302], [78600, 309], [78900, 327], [79200, 316], [79500, 313], [79800, 295], [80100, 327], [80400, 318], [80700, 312], [81000, 384], [81300, 486], [81600, 516], [81900, 553], [82200, 559], [82500, 589], [82800, 575], [83100, 606], [83400, 522], [83700, 572], [84000, 546], [84300, 452], [84600, 408], [84900, 330], [85200, 311], [85500, 222], [85800, 148], [86100, 77]]
# [[35], [26], [30], [24], [52], [20], [37], [23], [47], [21], [30], [14], [31], [19], [36], [22], [50], [19], [46], [22], [39], [17], [41], [24], [46], [22], [44], [20], [40], [14], [49], [16], [37], [20], [44], [14], [57]]

# %%
"""from tkinter import * 
import time


nbstep = 24*3600
yes=0
bon=0

a='white'
b='white'
c='white'
d='white'
e='white'
f='white'
g='white'
h='white'
i='white'
j='white'
k='white'
l='white'
m='white'
n='white'
o='white'
p='white'
q='white'
r='white'
s='white'
t='white'
u='white'
v='white'
w='white'
x='white'
y='white'
z='white'
aa='white'
bb='white'
cc='white'
dd='white'
ee='white'
ff='white'
gg='white'
hh='white'
ii='white'
jj='white'
kk='white'
fenetre = Tk()

photo = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")

canvas = Canvas(fenetre,width=1440, height=480)
canvas.create_image(0, 0, anchor=NW, image=photo)

canvas.create_oval(231,256,247,272,fill=a)
canvas.create_oval(255,256,270,272,fill=b)
canvas.create_oval(285,256,300,272,fill=c)
canvas.create_oval(315,256,330,272,fill=d)
canvas.create_oval(350,256,365,272,fill=e)
canvas.create_oval(382,256,397,272,fill=f)
canvas.create_oval(412,256,427,272,fill=g)
canvas.create_oval(440,256,455,272,fill=h)
canvas.create_oval(470,256,485,272,fill=i)

canvas.create_oval(502,256,517,272,fill=j)
canvas.create_oval(530,256,545,272,fill=k)
canvas.create_oval(555,256,570,272,fill=l)
canvas.create_oval(582,256,597,272,fill=m)
canvas.create_oval(610,256,625,272,fill=n)
canvas.create_oval(638,256,653,272,fill=o)
canvas.create_oval(665,256,680,272,fill=p)
canvas.create_oval(692,256,707,272,fill=q)
canvas.create_oval(720,256,735,272,fill=r)

canvas.create_oval(747,256,762,272,fill=s)
canvas.create_oval(775,256,790,272,fill=t)
canvas.create_oval(807,256,822,272,fill=u)
canvas.create_oval(839,256,854,272,fill=v)
canvas.create_oval(880,256,895,272,fill=w)
canvas.create_oval(910,256,925,272,fill=x)
canvas.create_oval(940,256,955,272,fill=y)
canvas.create_oval(972,256,987,272,fill=z)
canvas.create_oval(1000,256,1015,272,fill=aa)

canvas.create_oval(1030,256,1045,272,fill=bb)
canvas.create_oval(1060,256,1075,272,fill=cc)
canvas.create_oval(1093,256,1108,272,fill=dd)
canvas.create_oval(1123,256,1138,272,fill=ee)
canvas.create_oval(1155,256,1170,272,fill=ff)
canvas.create_oval(1185,256,1200,272,fill=gg)
canvas.create_oval(1214,256,1229,272,fill=hh)
canvas.create_oval(1245,256,1260,272,fill=ii)
canvas.create_oval(1280,256,1295,272,fill=jj)

canvas.create_oval(1310,256,1325,272,fill=kk)

canvas.pack()
for ok in range(nbstep):
    simulation(L_gare,L_train,L_dest_gare,L_dest_train,bon,yes,150,7000)
    yes+=1
    bon+=1

    
    if (ok%3600==0):
        if (L_gare[0][0]<100):
            a='white'
        elif (L_gare[0][0]<200):
            a='grey'
        elif (L_gare[0][0]<300):
            a='black'
        else:
            a='red'

        if (L_gare[1][0]<100):
            b='white'
        elif (L_gare[1][0]<200):
            b='grey'
        elif (L_gare[1][0]<300):
            b='black'
        else:
            b='red'

        if (L_gare[2][0]<100):
            c='white'
        elif (L_gare[2][0]<200):
            c='grey'
        elif (L_gare[2][0]<300):
            c='black'
        else:
            c='red'

        if (L_gare[3][0]<100):
            d='white'
        elif (L_gare[3][0]<200):
            d='grey'
        elif (L_gare[3][0]<300):
            d='black'
        else:
            d='red'

        if (L_gare[4][0]<100):
            e='white'
        elif (L_gare[4][0]<200):
            e='grey'
        elif (L_gare[4][0]<300):
            e='black'
        else:
            e='red'

        if (L_gare[5][0]<100):
            f='white'
        elif (L_gare[5][0]<200):
            f='grey'
        elif (L_gare[5][0]<300):
            f='black'
        else:
            f='red'

        if (L_gare[6][0]<100):
            g='white'
        elif (L_gare[6][0]<200):
            g='grey'
        elif (L_gare[6][0]<300):
            g='black'
        else:
            g='red'

        if (L_gare[7][0]<100):
            h='white'
        elif (L_gare[7][0]<200):
            h='grey'
        elif (L_gare[7][0]<300):
            h='black'
        else:
            h='red'

        if (L_gare[8][0]<100):
            i='white'
        elif (L_gare[8][0]<200):
            i='grey'
        elif (L_gare[8][0]<300):
            i='black'
        else:
            i='red'

        if (L_gare[9][0]<100):
            j='white'
        elif (L_gare[9][0]<200):
            j='grey'
        elif (L_gare[9][0]<300):
            j='black'
        else:
            j='red'

        if (L_gare[10][0]<100):
            k='white'
        elif (L_gare[10][0]<200):
            k='grey'
        elif (L_gare[10][0]<300):
            k='black'
        else:
            k='red'

        if (L_gare[11][0]<100):
            l='white'
        elif (L_gare[11][0]<200):
            l='grey'
        elif (L_gare[11][0]<300):
            l='black'
        else:
            l='red'

        if (L_gare[12][0]<100):
            m='white'
        elif (L_gare[12][0]<200):
            m='grey'
        elif (L_gare[12][0]<300):
            m='black'
        else:
            m='red'

        if (L_gare[13][0]<100):
            n='white'
        elif (L_gare[13][0]<200):
            n='grey'
        elif (L_gare[13][0]<300):
            n='black'
        else:
            n='red'

        if (L_gare[14][0]<100):
            o='white'
        elif (L_gare[14][0]<200):
            o='grey'
        elif (L_gare[14][0]<300):
            o='black'
        else:
            o='red'

        if (L_gare[15][0]<100):
            p='white'
        elif (L_gare[15][0]<200):
            p='grey'
        elif (L_gare[15][0]<300):
            p='black'
        else:
            p='red'

        if (L_gare[16][0]<100):
            q='white'
        elif (L_gare[16][0]<200):
            q='grey'
        elif (L_gare[16][0]<300):
            q='black'
        else:
            q='red'

        if (L_gare[17][0]<100):
            r='white'
        elif (L_gare[17][0]<200):
            r='grey'
        elif (L_gare[17][0]<300):
            r='black'
        else:
            r='red'

        if (L_gare[18][0]<100):
            s='white'
        elif (L_gare[18][0]<200):
            s='grey'
        elif (L_gare[18][0]<300):
            s='black'
        else:
            s='red'

        if (L_gare[19][0]<100):
            t='white'
        elif (L_gare[19][0]<200):
            t='grey'
        elif (L_gare[19][0]<300):
            t='black'
        else:
            t='red'

        if (L_gare[20][0]<100):
            u='white'
        elif (L_gare[20][0]<200):
            u='grey'
        elif (L_gare[20][0]<300):
            u='black'
        else:
            u='red'

        if (L_gare[21][0]<100):
            v='white'
        elif (L_gare[21][0]<200):
            v='grey'
        elif (L_gare[21][0]<300):
            v='black'
        else:
            v='red'

        if (L_gare[22][0]<100):
            w='white'
        elif (L_gare[22][0]<200):
            w='grey'
        elif (L_gare[22][0]<300):
            w='black'
        else:
            w='red'

        if (L_gare[23][0]<100):
            x='white'
        elif (L_gare[23][0]<200):
            x='grey'
        elif (L_gare[23][0]<300):
            x='black'
        else:
            x='red'

        if (L_gare[24][0]<100):
            y='white'
        elif (L_gare[24][0]<200):
            y='grey'
        elif (L_gare[24][0]<300):
            y='black'
        else:
            y='red'

        if (L_gare[25][0]<100):
            z='white'
        elif (L_gare[25][0]<200):
            z='grey'
        elif (L_gare[25][0]<300):
            z='black'
        else:
            z='red'

        if (L_gare[26][0]<100):
            aa='white'
        elif (L_gare[26][0]<200):
            aa='grey'
        elif (L_gare[26][0]<300):
            aa='black'
        else:
            aa='red'

        if (L_gare[27][0]<100):
            bb='white'
        elif (L_gare[27][0]<200):
            bb='grey'
        elif (L_gare[27][0]<300):
            bb='black'
        else:
            bb='red'

        if (L_gare[28][0]<100):
            cc='white'
        elif (L_gare[28][0]<200):
            cc='grey'
        elif (L_gare[28][0]<300):
            cc='black'
        else:
            cc='red'

        if (L_gare[29][0]<100):
            dd='white'
        elif (L_gare[29][0]<200):
            dd='grey'
        elif (L_gare[29][0]<300):
            dd='black'
        else:
            dd='red'

        if (L_gare[30][0]<100):
            ee='white'
        elif (L_gare[30][0]<200):
            ee='grey'
        elif (L_gare[30][0]<300):
            ee='black'
        else:
            ee='red'

        if (L_gare[31][0]<100):
            ff='white'
        elif (L_gare[31][0]<200):
            ff='grey'
        elif (L_gare[31][0]<300):
            ff='black'
        else:
            ff='red'

        if (L_gare[32][0]<100):
            gg='white'
        elif (L_gare[32][0]<200):
            gg='grey'
        elif (L_gare[32][0]<300):
            gg='black'
        else:
            gg='red'

        if (L_gare[33][0]<100):
            hh='white'
        elif (L_gare[33][0]<200):
            hh='grey'
        elif (L_gare[33][0]<300):
            hh='black'
        else:
            hh='red'

        if (L_gare[34][0]<100):
            ii='white'
        elif (L_gare[34][0]<200):
            ii='grey'
        elif (L_gare[34][0]<300):
            ii='black'
        else:
            ii='red'

        if (L_gare[35][0]<100):
            jj='white'
        elif (L_gare[35][0]<200):
            jj='grey'
        elif (L_gare[35][0]<300):
            jj='black'
        else:
            jj='red'

        if (L_gare[36][0]<100):
            kk='white'
        elif (L_gare[36][0]<200):
            kk='grey'
        elif (L_gare[36][0]<300):
            kk='black'
        else:
            kk='red'
        canvas.move()
        time.sleep(2)
        canvas.update()
    fenetre.mainloop()"""
# Out:
# 'from tkinter import * \nimport time\n\n\nnbstep = 24*3600\nyes=0\nbon=0\n\na=\'white\'\nb=\'white\'\nc=\'white\'\nd=\'white\'\ne=\'white\'\nf=\'white\'\ng=\'white\'\nh=\'white\'\ni=\'white\'\nj=\'white\'\nk=\'white\'\nl=\'white\'\nm=\'white\'\nn=\'white\'\no=\'white\'\np=\'white\'\nq=\'white\'\nr=\'white\'\ns=\'white\'\nt=\'white\'\nu=\'white\'\nv=\'white\'\nw=\'white\'\nx=\'white\'\ny=\'white\'\nz=\'white\'\naa=\'white\'\nbb=\'white\'\ncc=\'white\'\ndd=\'white\'\nee=\'white\'\nff=\'white\'\ngg=\'white\'\nhh=\'white\'\nii=\'white\'\njj=\'white\'\nkk=\'white\'\nfenetre = Tk()\n\nphoto = PhotoImage(master=fenetre, file="Parismetroline9map.pgm")\n\ncanvas = Canvas(fenetre,width=1440, height=480)\ncanvas.create_image(0, 0, anchor=NW, image=photo)\n\ncanvas.create_oval(231,256,247,272,fill=a)\ncanvas.create_oval(255,256,270,272,fill=b)\ncanvas.create_oval(285,256,300,272,fill=c)\ncanvas.create_oval(315,256,330,272,fill=d)\ncanvas.create_oval(350,256,365,272,fill=e)\ncanvas.create_oval(382,256,397,272,fill=f)\ncanvas.create_oval(412,256,427,272,fill=g)\ncanvas.create_oval(440,256,455,272,fill=h)\ncanvas.create_oval(470,256,485,272,fill=i)\n\ncanvas.create_oval(502,256,517,272,fill=j)\ncanvas.create_oval(530,256,545,272,fill=k)\ncanvas.create_oval(555,256,570,272,fill=l)\ncanvas.create_oval(582,256,597,272,fill=m)\ncanvas.create_oval(610,256,625,272,fill=n)\ncanvas.create_oval(638,256,653,272,fill=o)\ncanvas.create_oval(665,256,680,272,fill=p)\ncanvas.create_oval(692,256,707,272,fill=q)\ncanvas.create_oval(720,256,735,272,fill=r)\n\ncanvas.create_oval(747,256,762,272,fill=s)\ncanvas.create_oval(775,256,790,272,fill=t)\ncanvas.create_oval(807,256,822,272,fill=u)\ncanvas.create_oval(839,256,854,272,fill=v)\ncanvas.create_oval(880,256,895,272,fill=w)\ncanvas.create_oval(910,256,925,272,fill=x)\ncanvas.create_oval(940,256,955,272,fill=y)\ncanvas.create_oval(972,256,987,272,fill=z)\ncanvas.create_oval(1000,256,1015,272,fill=aa)\n\ncanvas.create_oval(1030,256,1045,272,fill=bb)\ncanvas.create_oval(1060,256,1075,272,fill=cc)\ncanvas.create_oval(1093,256,1108,272,fill=dd)\ncanvas.create_oval(1123,256,1138,272,fill=ee)\ncanvas.create_oval(1155,256,1170,272,fill=ff)\ncanvas.create_oval(1185,256,1200,272,fill=gg)\ncanvas.create_oval(1214,256,1229,272,fill=hh)\ncanvas.create_oval(1245,256,1260,272,fill=ii)\ncanvas.create_oval(1280,256,1295,272,fill=jj)\n\ncanvas.create_oval(1310,256,1325,272,fill=kk)\n\ncanvas.pack()\nfor ok in range(nbstep):\n    simulation(L_gare,L_train,L_dest_gare,L_dest_train,bon,yes,150,7000)\n    yes+=1\n    bon+=1\n\n    \n    if (ok%3600==0):\n        if (L_gare[0][0]<100):\n            a=\'white\'\n        elif (L_gare[0][0]<200):\n            a=\'grey\'\n        elif (L_gare[0][0]<300):\n            a=\'black\'\n        else:\n            a=\'red\'\n\n        if (L_gare[1][0]<100):\n            b=\'white\'\n        elif (L_gare[1][0]<200):\n            b=\'grey\'\n        elif (L_gare[1][0]<300):\n            b=\'black\'\n        else:\n            b=\'red\'\n\n        if (L_gare[2][0]<100):\n            c=\'white\'\n        elif (L_gare[2][0]<200):\n            c=\'grey\'\n        elif (L_gare[2][0]<300):\n            c=\'black\'\n        else:\n            c=\'red\'\n\n        if (L_gare[3][0]<100):\n            d=\'white\'\n        elif (L_gare[3][0]<200):\n            d=\'grey\'\n        elif (L_gare[3][0]<300):\n            d=\'black\'\n        else:\n            d=\'red\'\n\n        if (L_gare[4][0]<100):\n            e=\'white\'\n        elif (L_gare[4][0]<200):\n            e=\'grey\'\n        elif (L_gare[4][0]<300):\n            e=\'black\'\n        else:\n            e=\'red\'\n\n        if (L_gare[5][0]<100):\n            f=\'white\'\n        elif (L_gare[5][0]<200):\n            f=\'grey\'\n        elif (L_gare[5][0]<300):\n            f=\'black\'\n        else:\n            f=\'red\'\n\n        if (L_gare[6][0]<100):\n            g=\'white\'\n        elif (L_gare[6][0]<200):\n            g=\'grey\'\n     ...
